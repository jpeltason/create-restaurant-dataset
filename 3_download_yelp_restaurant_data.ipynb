# %%
import numpy as np
import pandas as pd
from yelpapi import YelpAPI
from googleplaces import GooglePlaces, types, lang
import googlemaps 
import gmaps as maps

# %%
# Open Yelp API key file and read key
# The file is assumed to contain only one single line with the API key

def read_file_content(filename):
    """ Given a filename,
        returns the content of this file
    """
    try:
        with open(filename, 'r') as f:
            return f.read()
    except FileNotFoundError:
        print("'%s' file not found" % filename)

YELP_API_KEY = read_file_content("./API Keys/YELP_API_KEY.txt")
yelp_api = YelpAPI(YELP_API_KEY, timeout_s=3.0)

# %%
# Configure Google Places
PLACES_API_KEY = read_file_content("./API Keys/GOOGLE_PLACES_API_KEY.txt")
gmaps = googlemaps.Client(key=PLACES_API_KEY)

# %% [markdown]
# ### Yelp Top 20 vs. Google Top 20 Restaurants in Stuttgart

# %% [markdown]
# Comparing the Top 20 results for Restaurants near Stuttgart from Google vs. Yelp, it seems that the Google ranking tends to prefer high-quality restaurants while the Yelp ranking tends to prefer restaurants visited frequently (e.g. 'Frittenwerk' vs. 'Hotel Royal', 'Biertargen im Schlossgarten' vs. 'Der Zauberlehrling')

# %%
# Lat/lng Stuttgart Hbf
lat_hbf = 48.783333
lng_hbf = 9.183333

# %%
# Top 20 restaurants in Stuttgart
response = yelp_api.search_query(term='restaurant', latitude=lat_hbf, longitude=lng_hbf, sort_by='best_match', limit=20)

# %%
def print_restaurant_names(response):
    restaurants = response['businesses']
    for rest in restaurants:
        print (rest['name'])
        
def get_restaurant_names(response):
    restaurant_list = []
    restaurants = response['businesses']
    for rest in restaurants:
        restaurant_list.append(rest['name'])
    return restaurant_list

# %%
print_restaurant_names(response)
# Out:
# Frittenwerk
# Biergarten im Schlossgarten
# Poffers Café Stuttgart
# Gaststätte Schlesinger
# Die Zirbelstube
# Kleinschmeckerei
# Takeshii's
# Aspendos
# Ramen 8
# Gravity
# Zum Becher
# Italiani
# Food Court
# L'Osteria
# Mandu
# Yorma's
# Rhythms Bar & Kitchen
# Cube
# Brauhaus Schönbuch
# Injeera

# %%
# Compare Top 20 Google results with top 20 Yelp results -> there is no common element
top_20_yelp = get_restaurant_names(response)

# Google Top 20, which we recieved earlier (but saved only the IDs) 
top_20_google = ['Hotel Royal', 'Der Zauberlehrling', 'Alte Kanzlei', 'Oggi', 'Enchilada Stuttgart', 
                 '5 Bar Gourmetrestaurant', 'Valle', 'Sky Beach Stuttgart', 'BLOCK HOUSE Eberhardstraße', 
                 'Arche Weinstube', 'VAPIANO Suttgart Bolzstrasse', 'Weinstube Fröhlich', 
                 'Paulaner am alten Postplatz', 'Prince of India', 'Hotel-Restaurant Köhler', 'Ambiente Africa', 
                 'MAREDO Steakhaus Stuttgart', 'BLOCK HOUSE Arnulf-Klett-Platz', 'CUBE Restaurant', 'Amici']

list(set(top_20_yelp) & set(top_20_google))
# Out:
# []

# %% [markdown]
# ### Download Yelp IDs based on Multiple Google Places Nearby Searches

# %% [markdown]
# Earlier we downloaded a list of ~1300 Google Place IDs for the most popular restaurants in Stuttgart area. The list was obtained by making multiple Google Places Nearby Searches around varying search centers. This list of IDs represents a good selection of restaurants (in terms of relevancy and quality of the restaurants), and the starting point for our Restaurant database.
#
# Since we are not allowed to save any Google Places data other than the ID, we need to gather the restaurant information from the Yelp API, matching the Google Places ID to the corresponding Yelp IDs.
#
# To do so, we first look up name and location at Google Places for each Google ID, then try to find the corresponding Yelp business by making a Yelp search_query based on name and location.

# %%
# For each restaurant id in the Google list, lookup name and geolocation at Google,
# then do a matching query at Yelp

google_restaurant_ids = np.array(
    pd.read_csv('./data/google_restaurant_ids.csv')['id'])

# %%
# For each Google ID, look up lat, lng, and name at Google Places
# Try to find matching Yelp Business based on name and geolocation.

yelp_ids_based_on_google = []
for google_id in google_restaurant_ids:
    print("Find Yelp ID for Google ID: {}".format(google_id))
    try:
        # Lookup name + geolocations at Google by ID 
        google_restaurant = gmaps.place(place_id=google_id)
        lat = google_restaurant['result']['geometry']['location']['lat']
        lng = google_restaurant['result']['geometry']['location']['lng']
        name = google_restaurant['result']['name']
        print("...restaurant {} at {}, {}".format(name, lat, lng))
        # Now try to find it at Yelp based on name and geolocation
        yelp_restaurant = yelp_api.search_query(term=name, latitude=lat, longitude=lng, radius=500, limit=2)
        #print(yelp_restaurant)
        yelp_id = yelp_restaurant['businesses'][0]['id']
        #print(yelp_restaurant['businesses'][0]['coordinates'])
        yelp_latitude = yelp_restaurant['businesses'][0]['coordinates']['latitude']
        yelp_longitude = yelp_restaurant['businesses'][0]['coordinates']['longitude']
        yelp_ids_based_on_google.append(yelp_id)
        print("...Yelp ID: {}".format(yelp_id))
    except Exception:
        try:
            print("No match found for Google name: {}".format(name))
        except Exeption:
            print("No match found for Google id: {}.format(google_id)")
        continue
# Out:
# Find Yelp ID for Google ID: ChIJdQ5X5XzPmUcRv7wL1Ond7Go
# No match found for Google name: Daily Burger
# Find Yelp ID for Google ID: ChIJCyT7XoDPmUcRVlr-BH_bNw8
# ...restaurant Restaurant "La Perla" im Schießsport-Zentrum at 48.8333999, 9.249574
# No match found for Google name: Restaurant "La Perla" im Schießsport-Zentrum
# Find Yelp ID for Google ID: ChIJleGdJZDJmUcRqozTDacuv14
# ...restaurant Andys Crepes at 48.8319935, 9.258655899999999
# No match found for Google name: Andys Crepes
# Find Yelp ID for Google ID: ChIJjzY04XzFmUcRkoCkdy647Co
# ...restaurant Restaurant TSV Steinhaldenfeld at 48.82968539999999, 9.2403472
# ...Yelp ID: -k0Ksk_FSzQAiKU6tdjayg
# Find Yelp ID for Google ID: ChIJbc5V5XzPmUcRHvMxfGR2Afw
# ...restaurant Oettingers Restaurant at 48.8340312, 9.2634533
# ...Yelp ID: -lWPadzpW-DFB0C6UHvX6w
# Find Yelp ID for Google ID: ChIJqxZJe5vFmUcRl6JkPcV7kGk
# ...restaurant Die Früchtle vom Schmidener Feld at 48.81933780000001, 9.254840100000001
# ...Yelp ID: 7Qvx3vZzuTNtB7kbCbQqZA
# Find Yelp ID for Google ID: ChIJF95OFXrPmUcRFpaz0a6wGIY
# ...restaurant Pizza Eis Da Toni at 48.83968, 9.262699999999999
# ...Yelp ID: F8hRwpv5F8rOyvmun1sBrw
# Find Yelp ID for Google ID: ChIJCUFvj2HFmUcRMYBmA6o_hso
# ...restaurant Konditorei Eresmann at 48.8316056, 9.2315878
# No match found for Google name: Konditorei Eresmann
# Find Yelp ID for Google ID: ChIJcbMk23zPmUcREkqMjEbc2WQ
# ...restaurant Pizzeria Carrettino at 48.8338889, 9.264444400000002
# No match found for Google name: Pizzeria Carrettino
# Find Yelp ID for Google ID: ChIJe4fF_n_PmUcR8o20y3sV_A4
# ...restaurant Ristorante Stadio at 48.83179349999999, 9.252273899999999
# ...Yelp ID: 5djuZfIkqf1ykQGbpWESrg
# Find Yelp ID for Google ID: ChIJq-VTe5vFmUcRg0r2ZzDmeno
# ...restaurant Bauerles at 48.818825, 9.2550226
# ...Yelp ID: AnzSQ92GlYTnE2R2TwKXiQ
# Find Yelp ID for Google ID: ChIJQ1XJw3zPmUcR6jaPSPZ5uRs
# ...restaurant Hotel Schmidener Eintracht at 48.8340516, 9.264240100000002
# ...Yelp ID: bMzd2Kb2mRM5RGBw_M48Yw
# Find Yelp ID for Google ID: ChIJGY-WF3jPmUcRlNlTmyMvgyI
# ...restaurant Schmiegs Kellerbesen at 48.84077000000001, 9.256340000000003
# ...Yelp ID: B-qhWHmFCRiJ8FNfxQhq3w
# Find Yelp ID for Google ID: ChIJQaFzgYfFmUcRIBOubUiqK08
# ...restaurant Marktgrill Karasawidis at 48.83062, 9.261519999999999
# No match found for Google name: Marktgrill Karasawidis
# Find Yelp ID for Google ID: ChIJnTBEq4HFmUcRGW765sIddSA
# ...restaurant Dionysos Fellbach at 48.8306504, 9.2615226
# No match found for Google name: Dionysos Fellbach
# Find Yelp ID for Google ID: ChIJWfWTdn3PmUcR6MQPwF3nfq8
# ...restaurant Das Kleine Restaurant at 48.8317226, 9.261925599999998
# No match found for Google name: Das Kleine Restaurant
# Find Yelp ID for Google ID: ChIJdQ5X5XzPmUcRc_OohO4jse0
# ...restaurant Im Schnitzbiegel at 48.8340471, 9.263445299999997
# ...Yelp ID: Pb2Q7JRPIEVh4jzZuTGR4w
# Find Yelp ID for Google ID: ChIJgTbnan3PmUcRCNOqmW64WqA
# ...restaurant Graffiti at 48.83192, 9.26315
# No match found for Google name: Graffiti
# Find Yelp ID for Google ID: ChIJOVELvSnpC0ERm8dIxROIZM8
# ...restaurant Imbiss Aronda at 48.8319738, 9.2631421
# ...Yelp ID: AmodNwe04PUrq2mjMVTCfA
# Find Yelp ID for Google ID: ChIJIa8PbH3PmUcR_HingPzwF1U
# ...restaurant Le Bistro at 48.8319504, 9.2634793
# No match found for Google name: Le Bistro
# Find Yelp ID for Google ID: ChIJbQyjIn3PmUcRua3FfDuYjBM
# ...restaurant Schmidener Pizza & Kebaphaus at 48.8326669, 9.26361
# ...Yelp ID: GNVa8QUMT6Vcvyee46Lp9w
# Find Yelp ID for Google ID: ChIJdbqGIn3PmUcRqHwO7gxdXb4
# ...restaurant Pizza und Dönerhaus Schmiden at 48.8327426, 9.263623700000002
# No match found for Google name: Pizza und Dönerhaus Schmiden
# Find Yelp ID for Google ID: ChIJg59V_DTPmUcRV0iY7cvmadk
# ...restaurant Döner Point Fellbach Schmiden at 48.83341, 9.263810000000001
# No match found for Google name: Döner Point Fellbach Schmiden
# Find Yelp ID for Google ID: ChIJ8aR-G5zPmUcRiUh3GukJI2U
# ...restaurant Q-Burger House at 48.8334197, 9.2638125
# No match found for Google name: Q-Burger House
# Find Yelp ID for Google ID: ChIJrbjrcGHFmUcRRiKCHlNFK4s
# ...restaurant China-Imbiss-Panda at 48.830294, 9.231447300000001
# ...Yelp ID: w-abucD2kGl-R0Z5tugM2g
# Find Yelp ID for Google ID: ChIJ33CFamTFmUcRK0_fVPynls0
# ...restaurant Eisele Angelika at 48.8268824, 9.2328457
# No match found for Google name: Eisele Angelika
# Find Yelp ID for Google ID: ChIJfR5vgGHFmUcRe2_0TU8bi_4
# ...restaurant Kneiple at 48.8303884, 9.2320941
# No match found for Google name: Kneiple
# Find Yelp ID for Google ID: ChIJW8j6G2vFmUcRn94fwl2FYQs
# ...restaurant Remstalstübchen at 48.8268562, 9.2326769
# No match found for Google name: Remstalstübchen
# Find Yelp ID for Google ID: ChIJocQ12IDPmUcRk8sfHJZs7Rk
# ...restaurant Eat Happy at 48.8408004, 9.257285699999999
# No match found for Google name: Eat Happy
# Find Yelp ID for Google ID: ChIJq6pNfmHFmUcRx_QUEtktnNQ
# ...restaurant Döner Shop at 48.8303567, 9.231866599999998
# No match found for Google name: Döner Shop
# Find Yelp ID for Google ID: ChIJxcqVfGHFmUcRGNtBFNKNm60
# ...restaurant Pascha Kebap at 48.83018240000001, 9.231836999999999
# No match found for Google name: Pascha Kebap
# Find Yelp ID for Google ID: ChIJW6AdOczFmUcRJT18hYgHV-8
# ...restaurant Flamingo Kebaphaus at 48.83105669999999, 9.2314268
# No match found for Google name: Flamingo Kebaphaus
# Find Yelp ID for Google ID: ChIJcyz48dzFmUcRKagCeE_rGds
# ...restaurant Restaurant Beirut at 48.8302187, 9.2313438
# No match found for Google name: Restaurant Beirut
# Find Yelp ID for Google ID: ChIJYSsz517FmUcRFyOapwp1QjA
# ...restaurant Shell at 48.83077549999999, 9.2214835
# No match found for Google name: Shell
# Find Yelp ID for Google ID: ChIJDbqOQfPPmUcRCff9OggBp5M
# ...restaurant Kentucky Fried Chicken at 48.8395508, 9.226145
# No match found for Google name: Kentucky Fried Chicken
# Find Yelp ID for Google ID: ChIJRdHxNvPPmUcRPKFNNAc4puc
# ...restaurant Kaufland Imbiss at 48.84007489999999, 9.2284236
# No match found for Google name: Kaufland Imbiss
# Find Yelp ID for Google ID: ChIJ-RdI2I3PmUcR_QS998zH4cc
# ...restaurant Blaustern Timbales at 48.8412604, 9.2356166
# No match found for Google name: Blaustern Timbales
# Find Yelp ID for Google ID: ChIJVdOgCY3PmUcR3b4SB8-MfMU
# ...restaurant Fehr Gastro KG at 48.8415366, 9.232337900000001
# No match found for Google name: Fehr Gastro KG
# Find Yelp ID for Google ID: ChIJUUT4xWnFmUcRAMU26Q8o3mg
# ...restaurant Gasthaus Rössle Stuttgart-Münster at 48.82052239999999, 9.223714499999998
# No match found for Google name: Gasthaus Rössle Stuttgart-Münster
# Find Yelp ID for Google ID: ChIJ8YqhwXHFmUcRIWJ6N51Fhc4
# ...restaurant Restaurant Steinhalde at 48.81933979999999, 9.236039100000001
# ...Yelp ID: Yn44IQ3dLCol_Iv6DYVaPQ
# Find Yelp ID for Google ID: ChIJJxivm1vFmUcRQWbm-WAt7AA
# ...restaurant Restaurant Bootshaus at 48.827304, 9.21703
# ...Yelp ID: hdH5ZB9pN5vLOLQkKroH5Q
# Find Yelp ID for Google ID: ChIJ1ZKVNI3PmUcR-jt0VimvvQs
# ...restaurant Pizza Car at 48.8420576, 9.2297174
# No match found for Google name: Pizza Car
# Find Yelp ID for Google ID: ChIJYXp4RYzPmUcRF5Fuu-2UVg0
# ...restaurant Neckarblick at 48.8398046, 9.232103100000002
# ...Yelp ID: wdCJ046Uzt02k1hhjHlECQ
# Find Yelp ID for Google ID: ChIJZdoICY3PmUcRRhMg5NU63nM
# ...restaurant McDonald's at 48.84152, 9.2323259
# ...Yelp ID: x9tg_wd_63tR639ca2fY_A
# Find Yelp ID for Google ID: ChIJFb8RRl_FmUcRrxNJ4VCjqBg
# ...restaurant Weinbau und Besenwirtschaft Nerz at 48.83313, 9.221119999999999
# No match found for Google name: Weinbau und Besenwirtschaft Nerz
# Find Yelp ID for Google ID: ChIJVxNgU_bPmUcRv3OXyfFFquE
# ...restaurant Haus am See at 48.83644049999999, 9.218336800000001
# ...Yelp ID: D2zpykCb4NfsOWoBUPXWnA
# Find Yelp ID for Google ID: ChIJJSPcA2nFmUcRU6n76aJepU4
# ...restaurant Weinstube Zom Bäcka Dais at 48.82086229999999, 9.226247299999999
# No match found for Google name: Weinstube Zom Bäcka Dais
# Find Yelp ID for Google ID: ChIJg_Tp3fTPmUcRBbHHe8Ps184
# ...restaurant Gasthaus zum Ochsen at 48.8364825, 9.2262211
# No match found for Google name: Gasthaus zum Ochsen
# Find Yelp ID for Google ID: ChIJseZ9qObPmUcRLlrJkmdVbOk
# ...restaurant Scheef's Sommerbesen at 48.8377555, 9.2291109
# No match found for Google name: Scheef's Sommerbesen
# Find Yelp ID for Google ID: ChIJY3za4WXPmUcRuOqZ7nYphOY
# ...restaurant Andys Crêpes at 48.8365997, 9.225584500000002
# No match found for Google name: Andys Crêpes
# Find Yelp ID for Google ID: ChIJ17KqpMvFmUcRteByqh8614Y
# ...restaurant Pizza Trullo‘s at 48.8332893, 9.2221604
# No match found for Google name: Pizza Trullo‘s
# Find Yelp ID for Google ID: ChIJM5ZhX4zPmUcRwLzsyq0PDmI
# ...restaurant Arschlöchle at 48.8398046, 9.232103100000002
# No match found for Google name: Arschlöchle
# Find Yelp ID for Google ID: ChIJL-TuR_bPmUcRDA0wgxOZTjI
# ...restaurant Treffpunkt am See at 48.83564000000001, 9.21872
# ...Yelp ID: noXKdbLQqpZPAiesHqPzdw
# Find Yelp ID for Google ID: ChIJq0yCCtfEmUcRJeLQt23fGOY
# ...restaurant Taverne Timbales at 48.8413185, 9.2357325
# No match found for Google name: Taverne Timbales
# Find Yelp ID for Google ID: ChIJB52jMvPPmUcRAE__uR8-qqU
# ...restaurant Grillstation at 48.84043639999999, 9.2290019
# No match found for Google name: Grillstation
# Find Yelp ID for Google ID: ChIJYZpz2I3PmUcRmxwTc6Y-AuQ
# ...restaurant Stuttgart-Hofen at 48.84128, 9.23577
# No match found for Google name: Stuttgart-Hofen
# Find Yelp ID for Google ID: ChIJYZpz2I3PmUcRGNHLiqVQjlg
# ...restaurant Vereinsgaststätte SKG Stuttgart at 48.84128, 9.23577
# No match found for Google name: Vereinsgaststätte SKG Stuttgart
# Find Yelp ID for Google ID: ChIJndRjaWzPmUcR2H9-pW0b-uM
# ...restaurant Ice and Roll/Cake and Roll Mühlhausen at 48.84050070000001, 9.229128400000002
# No match found for Google name: Ice and Roll/Cake and Roll Mühlhausen
# Find Yelp ID for Google ID: ChIJ1UtRzPLPmUcR9OxHXrw0Ugg
# ...restaurant Gasthaus Rössle at 48.84196849999999, 9.2294827
# ...Yelp ID: H4ZdcWunsi60UOw6a2axFQ
# Find Yelp ID for Google ID: ChIJgbtVbI3PmUcR3idBdUmudho
# ...restaurant Gaststätte Lamm at 48.84229999999999, 9.23189
# No match found for Google name: Gaststätte Lamm
# Find Yelp ID for Google ID: ChIJC89k-azFmUcRBEF27bhakB0
# ...restaurant Eat Happy at 48.8176952, 9.2396799
# No match found for Google name: Eat Happy
# Find Yelp ID for Google ID: ChIJb6DONI3PmUcRfIwXXg2FheI
# ...restaurant Rosario Poliselli Pizzeria at 48.842102, 9.2296529
# No match found for Google name: Rosario Poliselli Pizzeria
# Find Yelp ID for Google ID: ChIJa2AgPcbPmUcRA8-DAhN9j1c
# ...restaurant See at 48.83607, 9.218330000000002
# ...Yelp ID: BvLA5ZmP4vsy6JxSZ17AEg
# Find Yelp ID for Google ID: ChIJFw-oSY3PmUcR-TWjvghuLWg
# ...restaurant Löwen at 48.8424199, 9.230287200000001
# No match found for Google name: Löwen
# Find Yelp ID for Google ID: ChIJ5Q8KS_DPmUcR04HajNZugjg
# ...restaurant Mehl-Werk Food Lieferservice at 48.8430365, 9.2200176
# No match found for Google name: Mehl-Werk Food Lieferservice
# Find Yelp ID for Google ID: ChIJzYxjyvHPmUcRJKT90o621mU
# ...restaurant Bistro Steki 2001 at 48.8430928, 9.2206175
# No match found for Google name: Bistro Steki 2001
# Find Yelp ID for Google ID: ChIJP76et1rFmUcRgp6jfMhpRs0
# ...restaurant Ristorante Pizzeria Da Mamma Maria at 48.8251859, 9.212585100000002
# No match found for Google name: Ristorante Pizzeria Da Mamma Maria
# Find Yelp ID for Google ID: ChIJM3mQlP_PmUcRiZKVKH_ZCtc
# ...restaurant Creme Caramel Eisdiele - Stuttgart at 48.835795, 9.2028307
# No match found for Google name: Creme Caramel Eisdiele - Stuttgart
# Find Yelp ID for Google ID: ChIJH2QM__fPmUcRIFIlqO8nmAk
# ...restaurant Restaurant auf der Halbinsel am Max-Eyth-See at 48.83484139999999, 9.214484700000002
# No match found for Google name: Restaurant auf der Halbinsel am Max-Eyth-See
# Find Yelp ID for Google ID: ChIJHSkM__fPmUcRoD9b8FR87fI
# ...restaurant DOCK SNYDER - Max-Eyth-See at 48.83492700000001, 9.214479
# No match found for Google name: DOCK SNYDER - Max-Eyth-See
# Find Yelp ID for Google ID: ChIJIY4ph0TFmUcRr2qDCJsImSw
# ...restaurant Zur Alten Ziegelei at 48.82151700000001, 9.205814000000002
# ...Yelp ID: 13Q6IzWq2vLMBrsQbUKorw
# Find Yelp ID for Google ID: ChIJ97xJciPFmUcRxSMCUp8DCb8
# ...restaurant Riverhouse at 48.8318585, 9.207215399999999
# No match found for Google name: Riverhouse
# Find Yelp ID for Google ID: ChIJxfa-tkPFmUcRdRhFGIRVtDo
# ...restaurant Schwaben Bräu at 48.82060920000001, 9.218878300000002
# No match found for Google name: Schwaben Bräu
# Find Yelp ID for Google ID: ChIJ6dJbjpDFmUcR1Fzjiev_GBk
# ...restaurant Münster Kebap & Pizza Haus at 48.8198642, 9.2183126
# No match found for Google name: Münster Kebap & Pizza Haus
# Find Yelp ID for Google ID: ChIJKS4UaPLPmUcRn9xpRPXC9Aw
# ...restaurant Ristorante Pizzeria - il gusto Italiano at 48.8404241, 9.2155284
# No match found for Google name: Ristorante Pizzeria - il gusto Italiano
# Find Yelp ID for Google ID: ChIJJzTj9v_PmUcRRe46a2ZmzNU
# ...restaurant Da Lellla at 48.8353157, 9.2024087
# No match found for Google name: Da Lellla
# Find Yelp ID for Google ID: ChIJuUj4vKjFmUcRCya104RFrcw
# ...restaurant 2 BAKE & COOK at 48.82193590000001, 9.207676000000001
# No match found for Google name: 2 BAKE & COOK
# Find Yelp ID for Google ID: ChIJp4b6WOjFmUcRBmEeVBrBdjY
# ...restaurant Sportgaststätte Fairplay TSV Münster at 48.81732289999999, 9.222662
# No match found for Google name: Sportgaststätte Fairplay TSV Münster
# Find Yelp ID for Google ID: ChIJq6p6bGrFmUcRIjrZDDBqsDA
# ...restaurant TSV Münster Club-Restaurant at 48.81732289999999, 9.222662
# No match found for Google name: TSV Münster Club-Restaurant
# Find Yelp ID for Google ID: ChIJc2tO6E7FmUcRO0SIjPi30Gw
# ...restaurant Gaststätten-und Automatenaufstellung Lang GmbH at 48.8215236, 9.2058184
# No match found for Google name: Gaststätten-und Automatenaufstellung Lang GmbH
# Find Yelp ID for Google ID: ChIJkT2F6U7FmUcRF-okiI7BPP8
# ...restaurant Lang GmbH at 48.82154999999999, 9.205639999999999
# No match found for Google name: Lang GmbH
# Find Yelp ID for Google ID: ChIJUZXF9v_PmUcRNr_GHXplGCY
# ...restaurant Medya Kebab at 48.8358623, 9.202903899999999
# No match found for Google name: Medya Kebab
# Find Yelp ID for Google ID: ChIJM3mQlP_PmUcRmiUg1-1qERw
# ...restaurant Medya Kebap at 48.835795, 9.2028307
# No match found for Google name: Medya Kebap
# Find Yelp ID for Google ID: ChIJmW7T1ajamUcRiAsSicVcp8M
# ...restaurant Dionysos at 48.8317978, 9.1906703
# No match found for Google name: Dionysos
# Find Yelp ID for Google ID: ChIJ49QyjqzamUcR-3RsLC9z-9g
# ...restaurant Restaurant Tapach at 48.83063120000001, 9.198253600000001
# ...Yelp ID: mTBUCtgZRDE_zhdxQFl6KA
# Find Yelp ID for Google ID: ChIJ-2TIezbFmUcRk1rJwDiKbTE
# ...restaurant BEM Folk Dance Ensemble at 48.8254433, 9.1980215
# No match found for Google name: BEM Folk Dance Ensemble
# Find Yelp ID for Google ID: ChIJR58o8P3PmUcRPW8eP9J0Xc0
# ...restaurant Grillhähnchen Stuttgart at 48.8412962, 9.204391999999999
# No match found for Google name: Grillhähnchen Stuttgart
# Find Yelp ID for Google ID: ChIJoQ7qZynpC0ER9llOdkbed6o
# ...restaurant Toni's Pizzaservice at 48.83359859999999, 9.1900421
# ...Yelp ID: K5ZxzEqwD8Z1O8Ro4t6iDw
# Find Yelp ID for Google ID: ChIJmX7dUa_amUcR7KLGj2sjevY
# ...restaurant Angel Pizza at 48.83124249999999, 9.1883613
# No match found for Google name: Angel Pizza
# Find Yelp ID for Google ID: ChIJsTDgVK3amUcR6FsxhqI4itI
# ...restaurant Neuer Pfefferer at 48.8259085, 9.198499799999999
# ...Yelp ID: u9OmYtu13Y4NQhznlGf7Eg
# Find Yelp ID for Google ID: ChIJR5VrN0zFmUcRcAvxts90nNY
# ...restaurant Gaststätte Schützenhaus beim Dimi Stuttgart at 48.8222524, 9.2022015
# No match found for Google name: Gaststätte Schützenhaus beim Dimi Stuttgart
# Find Yelp ID for Google ID: ChIJ3xvZyqvamUcRpDw6EkWdpqg
# ...restaurant Eat Up at 48.83355609999999, 9.195942199999998
# ...Yelp ID: e7bRkZ4q8ibT-7M19g8Uxw
# Find Yelp ID for Google ID: ChIJNbeSR6ramUcRAcJLmxQIFL8
# ...restaurant Turnverein 1889 Zuffenhausen e.V. at 48.8342792, 9.1965076
# No match found for Google name: Turnverein 1889 Zuffenhausen e.V.
# Find Yelp ID for Google ID: ChIJve54JrDPmUcRI8uyf4Xqnp8
# ...restaurant Hahn im Korb at 48.837784, 9.2030893
# No match found for Google name: Hahn im Korb
# Find Yelp ID for Google ID: ChIJqz3zMKramUcR4ZzAtD6gXdU
# ...restaurant Can Döner at 48.8341681, 9.195878799999997
# No match found for Google name: Can Döner
# Find Yelp ID for Google ID: ChIJqy966a7amUcRpGiP661NGT0
# ...restaurant Restaurant S.V. Rot, Kadri Imishti at 48.83073210000001, 9.192434600000002
# No match found for Google name: Restaurant S.V. Rot, Kadri Imishti
# Find Yelp ID for Google ID: ChIJJ3orM6_amUcRn8Zkd82X6ec
# ...restaurant SushiYuma - Lieferservice at 48.8315547, 9.1897381
# No match found for Google name: SushiYuma - Lieferservice
# Find Yelp ID for Google ID: ChIJKWXqM6_amUcRBkEAcmzvX9s
# ...restaurant Gaststätte Krone at 48.8313455, 9.189621199999998
# No match found for Google name: Gaststätte Krone
# Find Yelp ID for Google ID: ChIJEU1tP_zPmUcRycFkKzU6RT4
# ...restaurant Am Eck at 48.8414704, 9.2080985
# No match found for Google name: Am Eck
# Find Yelp ID for Google ID: ChIJMSQ6N_zPmUcRqGfXcDTU46M
# ...restaurant Bäckerei Böhm GmbH at 48.8416691, 9.2083277
# No match found for Google name: Bäckerei Böhm GmbH
# Find Yelp ID for Google ID: ChIJ40x44gPQmUcR1YX2QW2foN0
# ...restaurant Gasthaus Krone at 48.8410636, 9.1981596
# No match found for Google name: Gasthaus Krone
# Find Yelp ID for Google ID: ChIJt4_uNUrFmUcRv6_SqW5xbLo
# ...restaurant Maxs Gastronomie GmbH at 48.81775, 9.2008
# No match found for Google name: Maxs Gastronomie GmbH
# Find Yelp ID for Google ID: ChIJlZCHLMnbmUcRtH_jgDKRYG0
# ...restaurant Istanbul Kebab at 48.8317786, 9.1867054
# No match found for Google name: Istanbul Kebab
# Find Yelp ID for Google ID: ChIJBfOl5KPbmUcRMckqqqaAfeM
# ...restaurant مطعم الجنة at 48.8304524, 9.1864378
# No match found for Google name: مطعم الجنة
# Find Yelp ID for Google ID: ChIJVVVljaXamUcR_CMrFL_4ero
# ...restaurant Tanzcafe at 48.8304524, 9.1864378
# No match found for Google name: Tanzcafe
# Find Yelp ID for Google ID: ChIJUwlkjaXamUcROUqqIELN3jE
# ...restaurant Amigo Pizza & China at 48.83047, 9.18642
# No match found for Google name: Amigo Pizza & China
# Find Yelp ID for Google ID: ChIJwR2n_KXamUcRmk3v_laVSCI
# ...restaurant Sweety | Eis - Crêpe - Coffee at 48.8313779, 9.1865063
# No match found for Google name: Sweety | Eis - Crêpe - Coffee
# Find Yelp ID for Google ID: ChIJZblWFKLamUcRJOKTYj_5roI
# ...restaurant EL CAMINO at 48.8315677, 9.176222200000002
# ...Yelp ID: cHRcof68g5nHHpSmobsxlA
# Find Yelp ID for Google ID: ChIJ7erhPaHamUcRorVV8MCWkR4
# ...restaurant JET Tankstelle at 48.8339, 9.1804
# No match found for Google name: JET Tankstelle
# Find Yelp ID for Google ID: ChIJ3TqX6aXamUcRvufDY1JDWFI
# ...restaurant dang Asian Cooking at 48.83099360000001, 9.1859017
# ...Yelp ID: GcSGFC-4jNiNKro5PwE9zw
# Find Yelp ID for Google ID: ChIJsTHIcKbamUcRqU7csRfdeko
# ...restaurant Schnitzelhaus Post at 48.8322646, 9.1854747
# No match found for Google name: Schnitzelhaus Post
# Find Yelp ID for Google ID: ChIJZ2CQ7qfamUcRzBnU3RFOGuU
# ...restaurant Ristorante Pizzeria Grüner Daumen at 48.8359568, 9.187838199999998
# No match found for Google name: Ristorante Pizzeria Grüner Daumen
# Find Yelp ID for Google ID: ChIJ6wJWDKLamUcR1epFMlff5e8
# ...restaurant Triple B – Beef Burger Brothers at 48.8301171, 9.175582199999997
# No match found for Google name: Triple B – Beef Burger Brothers
# Find Yelp ID for Google ID: ChIJaZ2Fx7XamUcRcrhK0TASfww
# ...restaurant Bäckerei Böhm GmbH at 48.8181422, 9.1911417
# No match found for Google name: Bäckerei Böhm GmbH
# Find Yelp ID for Google ID: ChIJvYB3XJ_amUcR5cEVMHFQ0ao
# ...restaurant Yuoki Restaurant at 48.8336974, 9.174943899999999
# ...Yelp ID: jGjijAKLnhEJol0zkBS3Bg
# Find Yelp ID for Google ID: ChIJc_N8xJjamUcR3DVO8qFJf8I
# ...restaurant Asia-Imbiss VAN at 48.8320363, 9.1727189
# ...Yelp ID: nLKyd54O1yL9SaAv08MaHQ
# Find Yelp ID for Google ID: ChIJSxj4w6DamUcRFmuCaTMr6r0
# ...restaurant Cafe Mozart at 48.83545729999999, 9.1811241
# ...Yelp ID: 0S3GEZUTHToSY-BI7lfOxw
# Find Yelp ID for Google ID: ChIJs-o6V5_amUcRnAnQM4HTrUE
# ...restaurant Ristorante Centrale at 48.8332393, 9.1747871
# ...Yelp ID: 7uAtZrPHw-xDaKhvuyswdg
# Find Yelp ID for Google ID: ChIJx42a6aXamUcR8toJPiWW8C0
# ...restaurant Fang at 48.83097790000001, 9.1859107
# No match found for Google name: Fang
# Find Yelp ID for Google ID: ChIJ_dcJvXTbmUcRKtZPWMayGMA
# ...restaurant Rot Kebap Haus at 48.83097180000001, 9.185831600000002
# No match found for Google name: Rot Kebap Haus
# Find Yelp ID for Google ID: ChIJU7kt0aXamUcRzLhkF0UVZxg
# ...restaurant Stern Kebap at 48.8316783, 9.1849747
# No match found for Google name: Stern Kebap
# Find Yelp ID for Google ID: ChIJjZN_-6bamUcRzXXgsIiSxBk
# ...restaurant Bistro Rotweg at 48.8342, 9.18459
# No match found for Google name: Bistro Rotweg
# Find Yelp ID for Google ID: ChIJ0ek8jKHamUcRYhCOOYMnR64
# ...restaurant Gaststätte Pflug at 48.8330235, 9.1771095
# No match found for Google name: Gaststätte Pflug
# Find Yelp ID for Google ID: ChIJKcr1Pb7bmUcRPvtj0xbetDQ
# ...restaurant Restaurant Hirsch schwäbische Küche at 48.8313374, 9.1756175
# No match found for Google name: Restaurant Hirsch schwäbische Küche
# Find Yelp ID for Google ID: ChIJi5TVR6rbmUcRKpzUW-MNZ_8
# ...restaurant Günther at 48.8276791, 9.1755625
# No match found for Google name: Günther
# Find Yelp ID for Google ID: ChIJC5T7J07bmUcRHrittoXXIYg
# ...restaurant City Kebap Zuffenhausen at 48.83156649999999, 9.175235899999997
# No match found for Google name: City Kebap Zuffenhausen
# Find Yelp ID for Google ID: ChIJAf5Bs8HbmUcRkdXTRY11zDM
# ...restaurant Lieferservice - La Sicilia in bocca at 48.83443339999999, 9.176322500000001
# No match found for Google name: Lieferservice - La Sicilia in bocca
# Find Yelp ID for Google ID: ChIJu6U4BgvQmUcRDDRPXEBCbac
# ...restaurant Hummelgraben at 48.84041759999999, 9.1803548
# ...Yelp ID: lm93Evg5OrT0D046VBklpg
# Find Yelp ID for Google ID: ChIJw_YyjPDbmUcRbx-2a1bBh_c
# ...restaurant Zampetis Leckereien Hausgemachter Gyros at 48.8320989, 9.1750805
# No match found for Google name: Zampetis Leckereien Hausgemachter Gyros
# Find Yelp ID for Google ID: ChIJefQjam3bmUcRhsdJOwgFAXg
# ...restaurant Keep it sucuk at 48.8317083, 9.174961399999999
# No match found for Google name: Keep it sucuk
# Find Yelp ID for Google ID: ChIJWzovnorbmUcRT6C3quKk8Uw
# ...restaurant I Love Sucuk at 48.83221630000001, 9.174685100000001
# No match found for Google name: I Love Sucuk
# Find Yelp ID for Google ID: ChIJ-6vfIpnbmUcRrDyZcyV4OPQ
# ...restaurant Caffe Tosca at 48.83318389999999, 9.1748393
# No match found for Google name: Caffe Tosca
# Find Yelp ID for Google ID: ChIJaR0BaNjbmUcR8-fDvv7oW_w
# ...restaurant Skylounge 327 at 48.81766529999999, 9.1925063
# No match found for Google name: Skylounge 327
# Find Yelp ID for Google ID: ChIJUTFVPWvbmUcR2KuHl1X8JG8
# ...restaurant Shisha at 48.8176564, 9.192585600000001
# No match found for Google name: Shisha
# Find Yelp ID for Google ID: ChIJ__8z25jamUcRmYxno5YVEbk
# ...restaurant Sefer Kebap Inh. Sefer Mustafa at 48.83206329999999, 9.172427299999999
# No match found for Google name: Sefer Kebap Inh. Sefer Mustafa
# Find Yelp ID for Google ID: ChIJS_hF25jamUcRX4O8hAZnNMo
# ...restaurant Ali Baba Döner at 48.8320704, 9.1723901
# No match found for Google name: Ali Baba Döner
# Find Yelp ID for Google ID: ChIJV3REaA_QmUcRkQD9EfcOh_E
# ...restaurant Club Restaurant at 48.84303999999999, 9.19037
# No match found for Google name: Club Restaurant
# Find Yelp ID for Google ID: ChIJ2_oq6mjbmUcRi-KXJgqQay4
# ...restaurant Wurst u. Brot at 48.83192750000001, 9.1721122
# No match found for Google name: Wurst u. Brot
# Find Yelp ID for Google ID: ChIJD8yYZ77amUcRU2x65WsZrjM
# ...restaurant McDonald's at 48.82123759999999, 9.173691000000002
# ...Yelp ID: rUauNnzpK8Wywb4Z5rVTGw
# Find Yelp ID for Google ID: ChIJW4HsL5jamUcRnbhzhfIA5HE
# ...restaurant Ulmers Besenwirtschaft at 48.8285372, 9.171231599999999
# ...Yelp ID: 3mRJxMHX7hi5dpOuGS7HXw
# Find Yelp ID for Google ID: ChIJ5cElt57amUcRYJ8gV5-6r_s
# ...restaurant Gaststätte Kirchtal at 48.8336535, 9.1700887
# No match found for Google name: Gaststätte Kirchtal
# Find Yelp ID for Google ID: ChIJh0fQ5L_amUcRkz02zEn6LGY
# ...restaurant Dedemoglu Baklava & Kebap Salonu at 48.8183968, 9.171011600000002
# No match found for Google name: Dedemoglu Baklava & Kebap Salonu
# Find Yelp ID for Google ID: ChIJYZKNJpfamUcRwcUDaBJCh-0
# ...restaurant Imbiss am Dehner at 48.826001, 9.167496000000002
# No match found for Google name: Imbiss am Dehner
# Find Yelp ID for Google ID: ChIJKya73b7amUcRhHIxux_BTeA
# ...restaurant Agip Service Station at 48.820646, 9.1753163
# No match found for Google name: Agip Service Station
# Find Yelp ID for Google ID: ChIJraK7C6LamUcRIJ4twsKcgmI
# ...restaurant Chen's Cooking Wok &Grill Restaurant at 48.8356018, 9.1632337
# ...Yelp ID: o05KsPVYO6dwjaxWuglkDw
# Find Yelp ID for Google ID: ChIJfXD32qHamUcRsGMJQgC8lco
# ...restaurant Los Locos Latinos Argentinische Steakhouse at 48.83662299999999, 9.163045
# No match found for Google name: Los Locos Latinos Argentinische Steakhouse
# Find Yelp ID for Google ID: ChIJm0DggLjamUcR9-G8BSJCPeU
# ...restaurant Schnauferl Grill at 48.8176928, 9.179449499999999
# ...Yelp ID: rXjd0vHQJeGXSfY5PqJoig
# Find Yelp ID for Google ID: ChIJ8Xluvp7amUcRoOpHg_wGtZ4
# ...restaurant Pizza Express Zuffenhausen Pizzaservice at 48.8343141, 9.170355400000002
# No match found for Google name: Pizza Express Zuffenhausen Pizzaservice
# Find Yelp ID for Google ID: ChIJ1eN-hZnamUcRT0hsqLc_XSY
# ...restaurant Aslan Kebap-Haus at 48.83012399999999, 9.168206
# No match found for Google name: Aslan Kebap-Haus
# Find Yelp ID for Google ID: ChIJadP-RYTamUcRvcG5DMKbDJM
# ...restaurant Pasquale Pepe Gaststätte at 48.8322519, 9.157652299999999
# No match found for Google name: Pasquale Pepe Gaststätte
# Find Yelp ID for Google ID: ChIJqWPHA8DamUcRhCIhw0xyS30
# ...restaurant Göktaş Restaurant at 48.81748, 9.170589999999999
# No match found for Google name: Göktaş Restaurant
# Find Yelp ID for Google ID: ChIJF5x_csDamUcRUf1WjH0ecew
# ...restaurant Köfteci Tuncay Stuttgart at 48.8171451, 9.1717659
# No match found for Google name: Köfteci Tuncay Stuttgart
# Find Yelp ID for Google ID: ChIJs2olT5namUcRx2SmpVXHGcw
# ...restaurant Fäßle at 48.8328068, 9.1697089
# No match found for Google name: Fäßle
# Find Yelp ID for Google ID: ChIJ47Ev1p3amUcR6nwe3JHMOzw
# ...restaurant Weinstube zum Tröpfle at 48.83598509999999, 9.169606
# ...Yelp ID: mZ_q2M-TvBJe2DLKvkoRmQ
# Find Yelp ID for Google ID: ChIJh2q_Y_PbmUcRgtCdcrV1u20
# ...restaurant Mersin Tantuni at 48.82982599999999, 9.170672299999998
# No match found for Google name: Mersin Tantuni
# Find Yelp ID for Google ID: ChIJrw-RsZnamUcRtEVJSDZiPYo
# ...restaurant Bistro Relax at 48.8298273, 9.170542
# No match found for Google name: Bistro Relax
# Find Yelp ID for Google ID: ChIJFamXPJnamUcRmoFXekf3O9w
# ...restaurant EFSANE Kebap & Grillhouse at 48.83209799999999, 9.1707301
# No match found for Google name: EFSANE Kebap & Grillhouse
# Find Yelp ID for Google ID: ChIJ84FSOpnamUcRyiA9VtAcXfw
# ...restaurant MP Montageservice at 48.83188999999999, 9.17024
# No match found for Google name: MP Montageservice
# Find Yelp ID for Google ID: ChIJFwkYHJ_amUcR1vfqLKYgmKo
# ...restaurant Gambrinus Traditionelle Griechische Taverne at 48.8345563, 9.1727497
# No match found for Google name: Gambrinus Traditionelle Griechische Taverne
# Find Yelp ID for Google ID: ChIJJVZvcJnamUcR4_uJzwUQ72s
# ...restaurant EURASIEN GmbH Türkische Imbiß Spezialitäten at 48.8312132, 9.169019099999998
# No match found for Google name: EURASIEN GmbH Türkische Imbiß Spezialitäten
# Find Yelp ID for Google ID: ChIJYV2KX2zbmUcRuISgmwN3xjY
# ...restaurant palmayr at 48.8322796, 9.169383800000002
# No match found for Google name: palmayr
# Find Yelp ID for Google ID: ChIJj6RTWpnamUcR6m-zRkwIpmY
# ...restaurant Kebap und Döner Arzum at 48.8324456, 9.1691131
# No match found for Google name: Kebap und Döner Arzum
# Find Yelp ID for Google ID: ChIJEZv-hZnamUcR4p4qxL37AKA
# ...restaurant Karma Döner at 48.83014679999999, 9.1682128
# No match found for Google name: Karma Döner
# Find Yelp ID for Google ID: ChIJRWjn-YDamUcRFJH6BUm535E
# ...restaurant Christophorus at 48.83431900000001, 9.151934
# ...Yelp ID: Xh44WtxgAA-rt33ne2gcGg
# Find Yelp ID for Google ID: ChIJjejuA3_amUcR9eMOUpfu4HU
# ...restaurant McDonald's at 48.83811300000001, 9.1474501
# ...Yelp ID: COj_DuOcCU-dYiopQPmeNw
# Find Yelp ID for Google ID: ChIJNyOO3YjamUcRQu2pOlibT44
# ...restaurant Badstüble Zuff at 48.827177, 9.152386200000002
# No match found for Google name: Badstüble Zuff
# Find Yelp ID for Google ID: ChIJm8k5baXamUcRPu4F99Xee7U
# ...restaurant Gaststätte Waldheim at 48.82808889999999, 9.153609399999997
# No match found for Google name: Gaststätte Waldheim
# Find Yelp ID for Google ID: ChIJgRTdz4namUcRBFLvvjaUDvQ
# ...restaurant Heimgarten Sankt Antonius at 48.82669, 9.148510000000002
# No match found for Google name: Heimgarten Sankt Antonius
# Find Yelp ID for Google ID: ChIJO1V9OInamUcRUGy1lI-E7yQ
# ...restaurant Vereinsgaststätte WALDBLICK Schlotwiese at 48.8257181, 9.152588699999999
# No match found for Google name: Vereinsgaststätte WALDBLICK Schlotwiese
# Find Yelp ID for Google ID: ChIJaUOX9uramUcRZIfUQuGONCQ
# ...restaurant JET Tankstelle at 48.817146, 9.167166199999999
# No match found for Google name: JET Tankstelle
# Find Yelp ID for Google ID: ChIJ44z6jYjamUcRxkEgXYvKm5g
# ...restaurant Tennis Club in Stuttgart - TC Blau-Weiß Zuffenhausen at 48.82854, 9.151959999999999
# No match found for Google name: Tennis Club in Stuttgart - TC Blau-Weiß Zuffenhausen
# Find Yelp ID for Google ID: ChIJKacf7JvamUcR0v0lYp6iT30
# ...restaurant RISTORANTE MANGIA! at 48.83241109999999, 9.167405599999999
# ...Yelp ID: TA2euZQYqRNJZTgr8B0Fow
# Find Yelp ID for Google ID: ChIJh5pHVu7amUcRfZaQS7ztBMA
# ...restaurant Burger.Place at 48.82910899999999, 9.164869
# No match found for Google name: Burger.Place
# Find Yelp ID for Google ID: ChIJi6JfZJramUcRezniTChZgxo
# ...restaurant The Indian Food corner at 48.82928599999999, 9.1652057
# No match found for Google name: The Indian Food corner
# Find Yelp ID for Google ID: ChIJf_5hVU3bmUcRnDr-ThL047k
# ...restaurant Strandhaus Bello Cane Italia Catering Party Foodtruck Europa at 48.8301227, 9.1662133
# No match found for Google name: Strandhaus Bello Cane Italia Catering Party Foodtruck Europa
# Find Yelp ID for Google ID: ChIJPwfUp5DamUcRcdLXBRWjc8I
# ...restaurant Pho a la Mama at 48.82823759999999, 9.16644
# ...Yelp ID: DZEQ3Ttn7JLPOMPWo2mwpg
# Find Yelp ID for Google ID: ChIJWyuywZvamUcRrWoqZUlO7-8
# ...restaurant Pizzeria da Micci at 48.8320165, 9.167020299999999
# No match found for Google name: Pizzeria da Micci
# Find Yelp ID for Google ID: ChIJE9xKY5vamUcRKSxltvsVTbU
# ...restaurant Café Restaurant Imigrante at 48.8333245, 9.1648047
# No match found for Google name: Café Restaurant Imigrante
# Find Yelp ID for Google ID: ChIJT02_mCnpC0ERIHaek0vajOo
# ...restaurant Franca e Franco at 48.8321534, 9.1575431
# ...Yelp ID: Cg08tX0SZIslFKJXQm_IOw
# Find Yelp ID for Google ID: ChIJAQCwcpzamUcRCPCwrO8E710
# ...restaurant Red Chili Triker at 48.8339591, 9.167378
# No match found for Google name: Red Chili Triker
# Find Yelp ID for Google ID: ChIJlZDifMPbmUcRAs45noguXnI
# ...restaurant Eat Happy at 48.8351936, 9.165317700000001
# No match found for Google name: Eat Happy
# Find Yelp ID for Google ID: ChIJSbmAadjbmUcRqODi6j13gm0
# ...restaurant Hunan Restaurant + Asia Markt at 48.83548680000001, 9.163043000000002
# No match found for Google name: Hunan Restaurant + Asia Markt
# Find Yelp ID for Google ID: ChIJR7Da65nbmUcR17iqEfH-6Ks
# ...restaurant WassiliosK at 48.8257043, 9.1685364
# No match found for Google name: WassiliosK
# Find Yelp ID for Google ID: ChIJvw2qSv3bmUcRReUGD-DdpPc
# ...restaurant Los Locos Latinos Bistro at 48.8368186, 9.162908999999999
# No match found for Google name: Los Locos Latinos Bistro
# Find Yelp ID for Google ID: ChIJ32Sp3oPamUcRDKoegjHhNeI
# ...restaurant Udo Zippenfenig - @Udo's Imbiss at 48.8357313, 9.157337799999999
# No match found for Google name: Udo Zippenfenig - @Udo's Imbiss
# Find Yelp ID for Google ID: ChIJHSR224PamUcRhMDmlM6zVc8
# ...restaurant Udo's Imbiss at 48.83579049999999, 9.1573829
# No match found for Google name: Udo's Imbiss
# Find Yelp ID for Google ID: ChIJpQlFw6zbmUcRYalb33qUCa8
# ...restaurant Restaurant il Sole at 48.82854, 9.151959999999999
# No match found for Google name: Restaurant il Sole
# Find Yelp ID for Google ID: ChIJiwzNouDbmUcR295Z18lIQFU
# ...restaurant Mamma Maria Zuffenhausen lieferservice at 48.8374818, 9.1622185
# No match found for Google name: Mamma Maria Zuffenhausen lieferservice
# Find Yelp ID for Google ID: ChIJZW55eHjamUcRhjBw9GMHrxI
# ...restaurant Hotel Neuwirtshaus at 48.8405677, 9.1414832
# ...Yelp ID: W4ldVyq3FSpsPGUxPAItTg
# Find Yelp ID for Google ID: ChIJC8KZO3jamUcRCj6yXBq6IpA
# ...restaurant Sportrestaurant Neuwirtshaus at 48.8382993, 9.140558300000002
# ...Yelp ID: MZKmrAWB5O05-NyC46TWRg
# Find Yelp ID for Google ID: ChIJVwiyLtboC0ERhnZtUrwIcDo
# ...restaurant Rostbraterei - TSV Korntal Vereinsgaststätte at 48.83015349999999, 9.1356446
# No match found for Google name: Rostbraterei - TSV Korntal Vereinsgaststätte
# Find Yelp ID for Google ID: ChIJy3F-eHjamUcRe_-XM_l7prw
# ...restaurant Restaurant Alte Hofkammer at 48.84057300000001, 9.141468999999999
# ...Yelp ID: TcPHZAVjOQ6yL5dDa_pMhg
# Find Yelp ID for Google ID: ChIJxUnOAn_amUcR7gkPHPs89Eg
# ...restaurant Il Punto at 48.8379109, 9.147667100000001
# ...Yelp ID: sI7_Qf-TRoX8MtNElWY2iQ
# Find Yelp ID for Google ID: ChIJ3_hDz4namUcRR2Sk8h8R3PA
# ...restaurant Luchterhand Bio-Catering at 48.8266667, 9.1486111
# No match found for Google name: Luchterhand Bio-Catering
# Find Yelp ID for Google ID: ChIJreu5M4famUcR-DySE7l6mPc
# ...restaurant Boxenstopp STUTTGART at 48.83404609999999, 9.151999500000002
# No match found for Google name: Boxenstopp STUTTGART
# Find Yelp ID for Google ID: ChIJNf0M4bXbmUcRx0LTb4HdNtA
# ...restaurant Vereinsheim Dietel at 48.8244207, 9.153329000000001
# No match found for Google name: Vereinsheim Dietel
# Find Yelp ID for Google ID: ChIJbQLj4kfbmUcRQS-gV5qk4JQ
# ...restaurant Indian Grill Station at 48.83704710000001, 9.149160400000001
# No match found for Google name: Indian Grill Station
# Find Yelp ID for Google ID: ChIJi63cq3_amUcRRnPCNxTeP94
# ...restaurant BIG BABA’s Kebabhouse at 48.83769139999999, 9.1477416
# No match found for Google name: BIG BABA’s Kebabhouse
# Find Yelp ID for Google ID: ChIJVRqHNPzbmUcRngld6xkc3DA
# ...restaurant Miroslav at 48.8301201, 9.136284300000002
# No match found for Google name: Miroslav
# Find Yelp ID for Google ID: ChIJb_Y6H3ramUcRlIAwzg-LxSk
# ...restaurant Rustical Vereinsheim der Gartenfreunde Grenzäcker at 48.83537339999999, 9.138789
# No match found for Google name: Rustical Vereinsheim der Gartenfreunde Grenzäcker
# Find Yelp ID for Google ID: ChIJBWy913HamUcRUkvrjkJYyJA
# ...restaurant Milano Lieferservice at 48.831228, 9.131924900000001
# No match found for Google name: Milano Lieferservice
# Find Yelp ID for Google ID: ChIJ__-_NZ3QmUcRl2W2aAxPi5E
# ...restaurant M&M Kebab und Grillhaus at 48.8418998, 9.1391353
# No match found for Google name: M&M Kebab und Grillhaus
# Find Yelp ID for Google ID: ChIJq5oyuRLamUcRCynvOYor2jk
# ...restaurant Bierakademie at 48.8307302, 9.1220182
# ...Yelp ID: c298GggKxC3Il8EijZTNOg
# Find Yelp ID for Google ID: ChIJf4MlXBLamUcRxgrP8fDgkx8
# ...restaurant Kornhaus Korntal at 48.83066, 9.119310000000004
# No match found for Google name: Kornhaus Korntal
# Find Yelp ID for Google ID: ChIJZwFyfm3amUcRJ8zdyk9i254
# ...restaurant Gaststätte Wirtschäftle at 48.8314844, 9.1260768
# No match found for Google name: Gaststätte Wirtschäftle
# Find Yelp ID for Google ID: ChIJlaYuQW3amUcRu00YsyxuDRs
# ...restaurant Mensa at 48.83065329999999, 9.124189699999999
# No match found for Google name: Mensa
# Find Yelp ID for Google ID: ChIJaXCKMY3bmUcR4MLhRBegsms
# ...restaurant Hofbräukeller Korntal at 48.8360354, 9.128083299999998
# No match found for Google name: Hofbräukeller Korntal
# Find Yelp ID for Google ID: ChIJ_7aQ1GzamUcRcSmIW0zJq9s
# ...restaurant China Restaurant Panda at 48.82907890000001, 9.1224938
# ...Yelp ID: BzfDofyFFw4gnVmiDJr3lQ
# Find Yelp ID for Google ID: ChIJd7_2u2namUcRj9nwefp2B3c
# ...restaurant Clubhaus Tachenberg at 48.822864, 9.128886800000002
# No match found for Google name: Clubhaus Tachenberg
# Find Yelp ID for Google ID: ChIJh_VOphTamUcRJrHRKNFv2nc
# ...restaurant Stern Kebap at 48.8267627, 9.120726699999999
# No match found for Google name: Stern Kebap
# Find Yelp ID for Google ID: ChIJzXBoQ2zbmUcRLAc2nXui_3Y
# ...restaurant Sternen Kebab at 48.8267505, 9.1207074
# ...Yelp ID: 7pThEw8fLTtTJ2POfX-v2A
# Find Yelp ID for Google ID: ChIJ0dO1-RLamUcRoEvP1GrnQEo
# ...restaurant Restaurant MoMentuM GbR at 48.82964130000001, 9.1198117
# No match found for Google name: Restaurant MoMentuM GbR
# Find Yelp ID for Google ID: ChIJewmCFe7RmUcRzeFEteEowq4
# ...restaurant Gaziantep Ocakbasi Kallenberg at 48.8420329, 9.1392045
# No match found for Google name: Gaziantep Ocakbasi Kallenberg
# Find Yelp ID for Google ID: ChIJienCCq7QmUcRRTbjJWwVQq8
# ...restaurant Die Currywurst - Hube’s Imbiss at 48.84204150000001, 9.139180800000002
# No match found for Google name: Die Currywurst - Hube’s Imbiss
# Find Yelp ID for Google ID: ChIJJz2UOuLRmUcRPmgHWWKzDu0
# ...restaurant Haugs at 48.8426303, 9.1381101
# No match found for Google name: Haugs
# Find Yelp ID for Google ID: ChIJWeayGD_amUcRymGFCYBnfrw
# ...restaurant E la Vita – Ristorante e Pizzeria at 48.81847899999999, 9.116211999999999
# No match found for Google name: E la Vita – Ristorante e Pizzeria
# Find Yelp ID for Google ID: ChIJaTG5Dz_amUcRVZiUgWsJjUo
# ...restaurant Pizza Service La Perla Stuttgart at 48.81916670000001, 9.116944400000001
# No match found for Google name: Pizza Service La Perla Stuttgart
# Find Yelp ID for Google ID: ChIJl5sk7hnamUcRQZEBZ_kApxI
# ...restaurant Imbiss Greco at 48.8249771, 9.1145561
# No match found for Google name: Imbiss Greco
# Find Yelp ID for Google ID: ChIJu_mTaknbmUcR7T3NZCGYqU0
# ...restaurant Metro Korntal Restaurant at 48.8269324, 9.109753999999999
# No match found for Google name: Metro Korntal Restaurant
# Find Yelp ID for Google ID: ChIJ6176fhjamUcRqV0PCO5QaKI
# ...restaurant Imbiss Gartenständle at 48.82356739999999, 9.1045499
# No match found for Google name: Imbiss Gartenständle
# Find Yelp ID for Google ID: ChIJydz3oorZmUcRMPtfwHZomS4
# ...restaurant Ristorante Italiani at 48.82258769999999, 9.094259999999998
# ...Yelp ID: lzsdcu4qJPcUCxNSqWZdYA
# Find Yelp ID for Google ID: ChIJIRJ1cWwLnkcRZXM26Vg-V30
# ...restaurant mömax Restaurant Stuttgart at 48.82017, 9.1012
# No match found for Google name: mömax Restaurant Stuttgart
# Find Yelp ID for Google ID: ChIJVc87jyDamUcRWCror9jJWa8
# ...restaurant Dolce Vita at 48.82126149999999, 9.0938748
# ...Yelp ID: KxlRX3ORVZ2R80icure9Wg
# Find Yelp ID for Google ID: ChIJXXsVXR_amUcR105Q1PRMzYE
# ...restaurant Ristorante San Felice at 48.8240957, 9.100319599999997
# No match found for Google name: Ristorante San Felice
# Find Yelp ID for Google ID: ChIJr9OsSWnbmUcRGUMUizDp8IU
# ...restaurant H8 Kantine im Holderpark at 48.8242887, 9.099318199999999
# No match found for Google name: H8 Kantine im Holderpark
# Find Yelp ID for Google ID: ChIJA2h1u0_bmUcRcqf455gvqTo
# ...restaurant Imbiss unter der Kastanie - Burger ~ Döner ~ Falafel ~ Lahmacun at 48.8224536, 9.095740200000002
# No match found for Google name: Imbiss unter der Kastanie - Burger ~ Döner ~ Falafel ~ Lahmacun
# Find Yelp ID for Google ID: ChIJS4B7FCHamUcRAUQRrUrBHf4
# ...restaurant Salve Pizza at 48.82035, 9.098375500000003
# No match found for Google name: Salve Pizza
# Find Yelp ID for Google ID: ChIJ0URXqpfFmUcRj046G3km4tk
# ...restaurant TobiDu Indoorspielplatz in Stuttgart Fellbach at 48.81283629999999, 9.262763399999997
# No match found for Google name: TobiDu Indoorspielplatz in Stuttgart Fellbach
# Find Yelp ID for Google ID: ChIJ9fU3WJTFmUcRRNjGqq_zEnI
# ...restaurant Asia World Fellbach at 48.8132618, 9.268133500000001
# No match found for Google name: Asia World Fellbach
# Find Yelp ID for Google ID: ChIJRRvsZ6LFmUcRSJMbO4Eub4A
# ...restaurant Wienerwald at 48.8098403, 9.253457899999997
# ...Yelp ID: xs16tHFHh6U7r3IrzO0XEA
# Find Yelp ID for Google ID: ChIJC5GmVL_oC0ERqH0VITOK0wc
# ...restaurant Mauritius Fellbach at 48.8132883, 9.2604718
# No match found for Google name: Mauritius Fellbach
# Find Yelp ID for Google ID: ChIJ87-xxJbFmUcRa5iE6oHNw9A
# ...restaurant NEON Grill Imbiss at 48.8145118, 9.2630956
# No match found for Google name: NEON Grill Imbiss
# Find Yelp ID for Google ID: ChIJN7RZCAzFmUcRd1DWITnhYKc
# ...restaurant Porto Elia at 48.8081808, 9.237516899999997
# ...Yelp ID: -ZeFBl2CX-snDy_zRvhCew
# Find Yelp ID for Google ID: ChIJCQR5DwzFmUcR8bgNJEZhpp8
# ...restaurant zum zwickel bad cannstatt at 48.8079658, 9.236925399999997
# No match found for Google name: zum zwickel bad cannstatt
# Find Yelp ID for Google ID: ChIJZXl1WgnFmUcRK-jvrkYCd3I
# ...restaurant Asia Service 2013 at 48.80698999999999, 9.23823
# No match found for Google name: Asia Service 2013
# Find Yelp ID for Google ID: ChIJtS7u8ZHFmUcRQ4UQ7V6qt5A
# ...restaurant RAUSCHENBERGER'S Supper Club - Pop Up Restaurant at 48.8194118, 9.266519299999999
# No match found for Google name: RAUSCHENBERGER'S Supper Club - Pop Up Restaurant
# Find Yelp ID for Google ID: ChIJv6m8NG3FmUcRoZEle8N50bs
# ...restaurant Classic Pizza Service at 48.81320639999999, 9.231029099999997
# No match found for Google name: Classic Pizza Service
# Find Yelp ID for Google ID: ChIJM41lhHTFmUcRvcwfTiNpiw4
# ...restaurant Kolping Kegelheim e.V. at 48.8140933, 9.240481599999999
# No match found for Google name: Kolping Kegelheim e.V.
# Find Yelp ID for Google ID: ChIJ14r5FZ7FmUcRlEs1-tJkmhw
# ...restaurant Gaststätte Sommerrain Restaurant at 48.815528, 9.247644
# No match found for Google name: Gaststätte Sommerrain Restaurant
# Find Yelp ID for Google ID: ChIJZXl1WgnFmUcRmrvdQggl4NA
# ...restaurant Domingo Pizza Service at 48.807044, 9.23837
# No match found for Google name: Domingo Pizza Service
# Find Yelp ID for Google ID: ChIJM-bX_qDFmUcRrlwLu8dnycA
# ...restaurant Gaststätte Christos Stube at 48.8088359, 9.247238399999999
# No match found for Google name: Gaststätte Christos Stube
# Find Yelp ID for Google ID: ChIJRfyoPJ7FmUcRu93bErPXXOc
# ...restaurant Gleis 1 Stüble at 48.8152218, 9.2474064
# No match found for Google name: Gleis 1 Stüble
# Find Yelp ID for Google ID: ChIJT8uWRaDFmUcR-r9YuGcjU5c
# ...restaurant Kolaha Gastro GmbH at 48.80994399999999, 9.2468855
# No match found for Google name: Kolaha Gastro GmbH
# Find Yelp ID for Google ID: ChIJ3TSaLenFmUcRRx5rdUzLEDE
# ...restaurant Bistro 33 - carpe diem at 48.8157116, 9.259349900000002
# No match found for Google name: Bistro 33 - carpe diem
# Find Yelp ID for Google ID: ChIJEw69RpTFmUcRcgU4FYMm73o
# ...restaurant Pronto Pizza da Stefano at 48.8097234, 9.254286899999999
# No match found for Google name: Pronto Pizza da Stefano
# Find Yelp ID for Google ID: ChIJRaNEaZfFmUcRJnJxOX8Q0Lk
# ...restaurant JET Tankstelle at 48.81480000000001, 9.2602
# No match found for Google name: JET Tankstelle
# Find Yelp ID for Google ID: ChIJn3ZqnqDFmUcRS3TPtF9Ems4
# ...restaurant Britan Crêpes & Falafel Spezialitäten at 48.8084, 9.24444
# No match found for Google name: Britan Crêpes & Falafel Spezialitäten
# Find Yelp ID for Google ID: ChIJcVJuIYXFmUcRhzgBWdTVjfE
# ...restaurant Cannstatter Combüse at 48.8083124, 9.244042
# No match found for Google name: Cannstatter Combüse
# Find Yelp ID for Google ID: ChIJ87-xxJbFmUcR2Vf6I2WAh4U
# ...restaurant Antalya Döner und Pizza at 48.81460389999999, 9.2631706
# No match found for Google name: Antalya Döner und Pizza
# Find Yelp ID for Google ID: ChIJSxe1-XvFmUcR8zC4U2aQjBY
# ...restaurant Al lado de casa at 48.81328490000001, 9.234334300000002
# No match found for Google name: Al lado de casa
# Find Yelp ID for Google ID: ChIJKfHHWwnFmUcRWhE1SULrlB4
# ...restaurant Domingo Pizza Service at 48.8071, 9.2383825
# No match found for Google name: Domingo Pizza Service
# Find Yelp ID for Google ID: ChIJ3bwgjLnFmUcRdxrripul3DI
# ...restaurant burgerme at 48.8069994, 9.2383995
# No match found for Google name: burgerme
# Find Yelp ID for Google ID: ChIJZXl1WgnFmUcRa2nRHqW9kGo
# ...restaurant Pizzeria Domino at 48.80698999999999, 9.23823
# No match found for Google name: Pizzeria Domino
# Find Yelp ID for Google ID: ChIJ-dBY3lnFmUcRd2ZicvqRRn8
# ...restaurant Mahrem Restaurant at 48.81386930000001, 9.232465500000002
# No match found for Google name: Mahrem Restaurant
# Find Yelp ID for Google ID: ChIJ_-iSNG3FmUcRH87z6TvYwt0
# ...restaurant Dara's Pizza Service at 48.81320639999999, 9.231029099999997
# ...Yelp ID: 6L7tz50A8rQBBQzn8T-wwQ
# Find Yelp ID for Google ID: ChIJMb2ijsHFmUcRVnSRGRoNuyQ
# ...restaurant Asia world restaurant Fellbach Stuttgarter Straße 62-64 at 48.8132307, 9.2681328
# No match found for Google name: Asia world restaurant Fellbach Stuttgarter Straße 62-64
# Find Yelp ID for Google ID: ChIJ3WpU8I3FmUcRZxCHpOHNPAc
# ...restaurant Betriebsrestaurant mezzogiorno, Im Landesamt für Besoldung und Versorgung at 48.820915, 9.268276
# No match found for Google name: Betriebsrestaurant mezzogiorno, Im Landesamt für Besoldung und Versorgung
# Find Yelp ID for Google ID: ChIJ4ZDa7pTFmUcR-woXGB2h5j0
# ...restaurant Amore Pizza Fellbach at 48.81381, 9.270189999999998
# No match found for Google name: Amore Pizza Fellbach
# Find Yelp ID for Google ID: ChIJwf0_Fg7FmUcRAVmx6GF_Jhs
# ...restaurant Krehl's Linde at 48.8067281, 9.2318894
# ...Yelp ID: 0cqpUbyTuMTWFWNRTFmySQ
# Find Yelp ID for Google ID: ChIJwf0_Fg7FmUcRf-7E26JWhSA
# ...restaurant Krehl’s Gastronomie at 48.8067305, 9.231868100000002
# No match found for Google name: Krehl’s Gastronomie
# Find Yelp ID for Google ID: ChIJLXLHPWvFmUcRiCkmMJJnEH4
# ...restaurant Gecko Restaurant und Eventlocation SpVgg Cannstatt at 48.8147222, 9.224999999999998
# No match found for Google name: Gecko Restaurant und Eventlocation SpVgg Cannstatt
# Find Yelp ID for Google ID: ChIJ4Ws7yRXFmUcRKOjpuE7VaqM
# ...restaurant Mike's Urban Pub - Stuttgart Bad Cannstatt at 48.80973299999999, 9.221691
# No match found for Google name: Mike's Urban Pub - Stuttgart Bad Cannstatt
# Find Yelp ID for Google ID: ChIJ-dkKcg_FmUcR7yL72To2Zdk
# ...restaurant Dam Dam Hot Pizzaservice at 48.8036722, 9.2338425
# No match found for Google name: Dam Dam Hot Pizzaservice
# Find Yelp ID for Google ID: ChIJid6NuhXFmUcR3b4b_mngyl0
# ...restaurant Namaskar at 48.810538, 9.221485999999999
# ...Yelp ID: fRmMC0WGAK3HRCg0mOCUpw
# Find Yelp ID for Google ID: ChIJt8pNlxbFmUcRC6CICH31xN4
# ...restaurant Kursaal Gastronomie at 48.808049, 9.22347
# No match found for Google name: Kursaal Gastronomie
# Find Yelp ID for Google ID: ChIJsULOWw7FmUcRKzgj-3MrFd0
# ...restaurant Agip Service Station at 48.80580020000001, 9.233372100000002
# No match found for Google name: Agip Service Station
# Find Yelp ID for Google ID: ChIJ6UZJahPFmUcRIyhkgTq2pto
# ...restaurant König - Pizza und Döner at 48.81192699999999, 9.2275005
# No match found for Google name: König - Pizza und Döner
# Find Yelp ID for Google ID: ChIJ33SjshbFmUcRcmQgFLXt9A8
# ...restaurant Kyotori Sushi & Asian at 48.81188979999999, 9.2274196
# No match found for Google name: Kyotori Sushi & Asian
# Find Yelp ID for Google ID: ChIJo7-01r7FmUcRPybzWw76DQg
# ...restaurant Trattoria Lina at 48.8080322, 9.227636500000001
# No match found for Google name: Trattoria Lina
# Find Yelp ID for Google ID: ChIJj1TKfhHFmUcRvudKAVPpRK0
# ...restaurant Trattoria Pizzeria Lina at 48.80793, 9.227789999999999
# No match found for Google name: Trattoria Pizzeria Lina
# Find Yelp ID for Google ID: ChIJAQBcOw7FmUcRY069dMXGHnY
# ...restaurant Gasthaus Jägerhaus at 48.80632110000001, 9.231649
# No match found for Google name: Gasthaus Jägerhaus
# Find Yelp ID for Google ID: ChIJi1RdOw7FmUcRDxaWnMxQBfM
# ...restaurant Meze Meze Bad Cannstatt at 48.80632110000001, 9.231649
# No match found for Google name: Meze Meze Bad Cannstatt
# Find Yelp ID for Google ID: ChIJi1RdOw7FmUcR1TGb8xlW7Vs
# ...restaurant Греческий ресторан at 48.8063005, 9.231666099999998
# No match found for Google name: Греческий ресторан
# Find Yelp ID for Google ID: ChIJHeWYJQ7FmUcR7UNkKsvx-jk
# ...restaurant Göz Kebap at 48.8061255, 9.231274299999997
# No match found for Google name: Göz Kebap
# Find Yelp ID for Google ID: ChIJGwlirxbFmUcRimtWEHgYvSU
# ...restaurant Augustiner Biergarten at 48.8080462, 9.224043499999999
# No match found for Google name: Augustiner Biergarten
# Find Yelp ID for Google ID: ChIJnx2UbbPFmUcRlNfQhn5kfGA
# ...restaurant Trattoria Oma Maria at 48.8080703, 9.2234509
# No match found for Google name: Trattoria Oma Maria
# Find Yelp ID for Google ID: ChIJ2YTpN3rFmUcRnge6pIB4ZIU
# ...restaurant Palmayr Schawarma Bad Cannstatt at 48.8096132, 9.220764599999999
# No match found for Google name: Palmayr Schawarma Bad Cannstatt
# Find Yelp ID for Google ID: ChIJheJ4plLFmUcRjSrit-bmKjQ
# ...restaurant Babbsadd at 48.8116768, 9.2180845
# No match found for Google name: Babbsadd
# Find Yelp ID for Google ID: ChIJkyhh6DjFmUcRmOaNnPHR2Kc
# ...restaurant PILUM at 48.8140411, 9.213177400000001
# ...Yelp ID: ysz5u6v3vTBrYOrdG1nnaA
# ...
# Find Yelp ID for Google ID: ChIJb94IpNzcmUcR67NEOg3dqFQ
# ...restaurant Hotel - Gasthof Adler at 48.7273293, 9.1468219
# No match found for Google name: Hotel - Gasthof Adler
# Find Yelp ID for Google ID: ChIJD6k5IdvcmUcRRKv38A0FyHM
# ...restaurant Gasthaus zur Linde - Trautweins Linde GmbH at 48.7276466, 9.1505018
# No match found for Google name: Gasthaus zur Linde - Trautweins Linde GmbH
# Find Yelp ID for Google ID: ChIJFw74dVfcmUcRekSNTfiky1w
# ...restaurant Pizza Blitz at 48.726296, 9.151083
# No match found for Google name: Pizza Blitz
# Find Yelp ID for Google ID: ChIJtdMus9zcmUcRbNfDqhFLdRc
# ...restaurant Hotel Restaurant Lindenhof at 48.72855999999999, 9.14672
# ...Yelp ID: hhVQlbCxibAiVV2jIyUerA
# Find Yelp ID for Google ID: ChIJgeXiLsXcmUcR9ijUcx6T_NY
# ...restaurant Möhringer Hexle at 48.72862689999999, 9.151299200000002
# No match found for Google name: Möhringer Hexle
# Find Yelp ID for Google ID: ChIJ4-AC7tzcmUcRozNzE73ZqK8
# ...restaurant Griechisches Restaurant Hirsch-Weinstuben Stuttgart at 48.7266861, 9.1449587
# No match found for Google name: Griechisches Restaurant Hirsch-Weinstuben Stuttgart
# Find Yelp ID for Google ID: ChIJ18odVNncmUcR8Bcpv7l7-6g
# ...restaurant Shell at 48.7232995, 9.146428299999998
# ...Yelp ID: NPf9SnTSdP0KRqs3YKQILg
# Find Yelp ID for Google ID: ChIJNy81ycTcmUcR_KaoMaMaLuA
# ...restaurant Restaurant Rembrandtstuben at 48.72875429999999, 9.149769299999999
# No match found for Google name: Restaurant Rembrandtstuben
# Find Yelp ID for Google ID: ChIJbbCb1U_cmUcRHjmMFJEQjk8
# ...restaurant Houstons Fine Burrito Company at 48.727554, 9.149446
# ...Yelp ID: vaWbRstNuDpEYFhh0XIBRw
# Find Yelp ID for Google ID: ChIJb8N_YdvcmUcRsJxEkXAf3CI
# ...restaurant Eiscafé & Restaurant Aurelia Stuttgart at 48.727028, 9.147482000000002
# No match found for Google name: Eiscafé & Restaurant Aurelia Stuttgart
# Find Yelp ID for Google ID: ChIJ_x2W1E7mC0ERQcOixCllAWM
# ...restaurant Il Cappuccino at 48.7272512, 9.147210399999999
# ...Yelp ID: 5XIitwbee5OL1PY19gIY3Q
# Find Yelp ID for Google ID: ChIJATDPd9zcmUcRkF7zGfpGPYM
# ...restaurant Gasthaus zum Lamm at 48.7250019, 9.146391599999998
# No match found for Google name: Gasthaus zum Lamm
# Find Yelp ID for Google ID: ChIJL1FjBNTcmUcR6r9wMpt8qTQ
# ...restaurant Chinapalast at 48.72196629999999, 9.1585156
# ...Yelp ID: MXDY_Apycm55iCSlLoDWtw
# Find Yelp ID for Google ID: ChIJi99OgdzcmUcRD6SX90O_eGU
# ...restaurant La Piazzetta Ristorante Pizzeria at 48.7263636, 9.1462286
# ...Yelp ID: ebhmMrsOSrflBYrh4expiA
# Find Yelp ID for Google ID: ChIJ1_Qc3NzcmUcRwx0xRFWEQcE
# ...restaurant Osteria Tra Noi at 48.72797449999999, 9.144770299999998
# ...Yelp ID: NInPF38byaGmmWW11O5dNA
# Find Yelp ID for Google ID: ChIJw_Wy18TcmUcRsw99BaNgK-I
# ...restaurant Taverne Saloniki at 48.7285952, 9.1507706
# ...Yelp ID: 7cu-HPvl31XSw5OZnLI-XQ
# Find Yelp ID for Google ID: ChIJn7Nj89rcmUcRKGkrVdgku7s
# ...restaurant Bravo Pizza at 48.7260678, 9.151450800000001
# No match found for Google name: Bravo Pizza
# Find Yelp ID for Google ID: ChIJ6TW28drcmUcRTV91pgYwagE
# ...restaurant Super Pizza-Service at 48.7263142, 9.1510594
# No match found for Google name: Super Pizza-Service
# Find Yelp ID for Google ID: ChIJs5zG3hndmUcRuN3QKUIYGRc
# ...restaurant Subway at 48.7226206, 9.1584836
# No match found for Google name: Subway
# Find Yelp ID for Google ID: ChIJryntNcXcmUcRW_pSSf_SCT4
# ...restaurant Trattoria da Schnecki at 48.7286111, 9.1525
# No match found for Google name: Trattoria da Schnecki
# Find Yelp ID for Google ID: ChIJiz_BScXcmUcRvUDJlX12tFM
# ...restaurant Gaststätte J. Möller at 48.7285716, 9.152487500000001
# No match found for Google name: Gaststätte J. Möller
# Find Yelp ID for Google ID: ChIJq6pm2MTcmUcRbH8DjRk2zOE
# ...restaurant Bistro-Pub Alte Hütte at 48.72905989999999, 9.150887099999998
# No match found for Google name: Bistro-Pub Alte Hütte
# Find Yelp ID for Google ID: ChIJLz6zptzcmUcR1iGHPxijLBs
# ...restaurant Metzgerei Bienzle at 48.72763, 9.147005000000002
# No match found for Google name: Metzgerei Bienzle
# Find Yelp ID for Google ID: ChIJf7oyN8PcmUcRp8mfzZ_ZUmw
# ...restaurant City Grill - Kebap & Pizza mit Gartenwirtschaft at 48.72913639999999, 9.1463529
# No match found for Google name: City Grill - Kebap & Pizza mit Gartenwirtschaft
# Find Yelp ID for Google ID: ChIJxZdLNMPcmUcRQR0PjRJ6IZQ
# ...restaurant Regenbogen Imbiss at 48.728964, 9.146191000000002
# ...Yelp ID: CVis_GSkrVlDwcoHfl3ILQ
# Find Yelp ID for Google ID: ChIJAQCwgNvcmUcRJ9l7QluAzf8
# ...restaurant Gaststätte Bären at 48.72579999999999, 9.1466699
# No match found for Google name: Gaststätte Bären
# Find Yelp ID for Google ID: ChIJq54-ASrdmUcR51Vi1NcLZnw
# ...restaurant Untere Körschmühle (Gastronomie) at 48.7174382, 9.1571117
# No match found for Google name: Untere Körschmühle (Gastronomie)
# Find Yelp ID for Google ID: ChIJh132h9zcmUcRfbpHdBizBMc
# ...restaurant Asia Imbiss Le at 48.7260123, 9.1461591
# ...Yelp ID: 8hq3YPLJ1Ibn0cinznfnDQ
# Find Yelp ID for Google ID: ChIJpRxe9dvcmUcRPIJwbfDu0mA
# ...restaurant Patrick's Stop - Jamaican Imbiss & Take Away at 48.7246037, 9.1464591
# No match found for Google name: Patrick's Stop - Jamaican Imbiss & Take Away
# Find Yelp ID for Google ID: ChIJj4SZ1t7cmUcRRe73Hn3368I
# ...restaurant AKZENT Hotel Möhringer Hof at 48.721096, 9.144618
# ...Yelp ID: tdsVbIHvwPWFO764eWArvw
# Find Yelp ID for Google ID: ChIJMxBCYifdmUcRjaIC5kvSIHc
# ...restaurant feinkost squisito at 48.71844, 9.146440000000002
# No match found for Google name: feinkost squisito
# Find Yelp ID for Google ID: ChIJv61J2dzcmUcRlxUdrJgyU-A
# ...restaurant Möhringer Pizza und Kebabhaus at 48.72787999999999, 9.144480000000001
# No match found for Google name: Möhringer Pizza und Kebabhaus
# Find Yelp ID for Google ID: ChIJZ7SxB9TdmUcRt4RGtDrdUUc
# ...restaurant Il Vulcano Ristorante Pizzeria at 48.72762729999999, 9.144417599999999
# No match found for Google name: Il Vulcano Ristorante Pizzeria
# Find Yelp ID for Google ID: ChIJhQtFi9zcmUcRwsLHnXp8S1M
# ...restaurant Momentos at 48.726394, 9.1453749
# ...Yelp ID: cJNw0OmXqYHumZsFFKtZFw
# Find Yelp ID for Google ID: ChIJc7ND_DfdmUcR35dusO7jnUY
# ...restaurant Gaumenschmaus Haenchen at 48.7272853, 9.1413418
# No match found for Google name: Gaumenschmaus Haenchen
# Find Yelp ID for Google ID: ChIJqZzRkufcmUcR-_0a_XpPEV8
# ...restaurant Mediterraneo By Tsakiris at 48.72787, 9.139999999999999
# No match found for Google name: Mediterraneo By Tsakiris
# Find Yelp ID for Google ID: ChIJqZzRkufcmUcR7P1L388Sfrc
# ...restaurant U Vaihinger Straße at 48.72787, 9.139999999999999
# No match found for Google name: U Vaihinger Straße
# Find Yelp ID for Google ID: ChIJPWfSjfzdmUcRx_DaNqxpih4
# ...restaurant Bowling & Billard Lounge at 48.7269723, 9.1348416
# No match found for Google name: Bowling & Billard Lounge
# Find Yelp ID for Google ID: ChIJ2fiBSifdmUcRV5mZbH254Mk
# ...restaurant SVM Gaststätte Zoam Schwoabentöpfle Inh. Christian Rault at 48.71744, 9.14416
# No match found for Google name: SVM Gaststätte Zoam Schwoabentöpfle Inh. Christian Rault
# Find Yelp ID for Google ID: ChIJMxBCYifdmUcRVA7VDheOz6o
# ...restaurant AMA Gastronomiebetrieb GmbH at 48.71844, 9.146440000000002
# No match found for Google name: AMA Gastronomiebetrieb GmbH
# Find Yelp ID for Google ID: ChIJ36uP2CrdmUcRG6jILWRMlZg
# ...restaurant Fuoco at 48.7182863, 9.146550399999999
# No match found for Google name: Fuoco
# Find Yelp ID for Google ID: ChIJJeGRH_zcmUcRpMhOw5QUhNs
# ...restaurant JET Tankstelle at 48.7242, 9.119399999999999
# ...Yelp ID: tBoInEbGGbO__sFOYUalBw
# Find Yelp ID for Google ID: ChIJzzjNifrcmUcR3mj1pOaQtlo
# ...restaurant Ilysia am Wallgraben at 48.7293431, 9.125270799999997
# ...Yelp ID: MLyDupR1LNSyQtmsks0JFA
# Find Yelp ID for Google ID: ChIJV_uw1vzcmUcRcOA5NG5NM58
# ...restaurant Burger King at 48.72316360000001, 9.125476800000003
# ...Yelp ID: 90_kiO2TZXVd8xCXj9cbig
# Find Yelp ID for Google ID: ChIJucDKsvjcmUcRREF25TGpq_s
# ...restaurant Imbi Spielhallen und Gaststätten GmbH at 48.7261704, 9.1160493
# No match found for Google name: Imbi Spielhallen und Gaststätten GmbH
# Find Yelp ID for Google ID: ChIJGzw7Rf7cmUcRAgNjFhMfcDw
# ...restaurant (Clubrestaurant Da Domenico )Franco & Toni at 48.72224900000001, 9.118865000000003
# No match found for Google name: (Clubrestaurant Da Domenico )Franco & Toni
# Find Yelp ID for Google ID: ChIJsbNEoPncmUcRYDpovkka-9A
# ...restaurant Bistro Panino at 48.7278421, 9.1216909
# No match found for Google name: Bistro Panino
# Find Yelp ID for Google ID: ChIJz0bGU-LcmUcRvHqSM4IZ5A4
# ...restaurant McDonald's at 48.7221144, 9.129662100000001
# ...Yelp ID: I36RcJBqCkyea4Fi-gTVEw
# Find Yelp ID for Google ID: ChIJU6MYA_7cmUcRWqah8LFQL5c
# ...restaurant Galileo-Stüble at 48.7209073, 9.118788499999999
# No match found for Google name: Galileo-Stüble
# Find Yelp ID for Google ID: ChIJVVVJg-LcmUcR_-ykRM0T-FI
# ...restaurant Restaurant im TTR at 48.72024099999999, 9.128101899999999
# No match found for Google name: Restaurant im TTR
# Find Yelp ID for Google ID: ChIJC6sYcP7cmUcR1ztRyT2JOIA
# ...restaurant TC Blau-Weiss Vaihingen-Rohr at 48.722226, 9.1188672
# No match found for Google name: TC Blau-Weiss Vaihingen-Rohr
# Find Yelp ID for Google ID: ChIJt1mS8PvcmUcRN9y2Nix7myA
# ...restaurant IBRG Hotelmanagement GmbH at 48.7261845, 9.1223408
# No match found for Google name: IBRG Hotelmanagement GmbH
# Find Yelp ID for Google ID: ChIJL_LvsPvcmUcRNeilUbM9Tfw
# ...restaurant Asia Bistro at 48.72745419999999, 9.1237721
# ...Yelp ID: O8AtgiDbu8zfofuiuBukYA
# Find Yelp ID for Google ID: ChIJQ_otBvvcmUcRM6V8EFLGlw8
# ...restaurant Mira Gaststätten GmbH at 48.727231, 9.124959200000001
# No match found for Google name: Mira Gaststätten GmbH
# Find Yelp ID for Google ID: ChIJOWh05-LcmUcRVAnwJCvU_ZM
# ...restaurant Bernd's Bistro GmbH at 48.722067, 9.1279518
# No match found for Google name: Bernd's Bistro GmbH
# Find Yelp ID for Google ID: ChIJq3Rm5uLcmUcRPFSM-a2W5ng
# ...restaurant Canteen B19 of Stollsteimer Catering & Events at 48.72197970000001, 9.1277577
# No match found for Google name: Canteen B19 of Stollsteimer Catering & Events
# Find Yelp ID for Google ID: ChIJ_zI1Q1PcmUcRsWozRk4o2-U
# ...restaurant Curryteria Imbiss at 48.72234520000001, 9.1254397
# ...Yelp ID: eRTQovFt230lUvOWmOvYdQ
# Find Yelp ID for Google ID: ChIJs__uceLcmUcRmnC5fwG1884
# ...restaurant Bischoff Dekra Club-Restaurant at 48.72041, 9.130069999999998
# No match found for Google name: Bischoff Dekra Club-Restaurant
# Find Yelp ID for Google ID: ChIJjd58ct3dmUcRJL7H-x8LuRo
# ...restaurant Neue Dönastie im Daimler AG Office V at 48.7247568, 9.1223696
# No match found for Google name: Neue Dönastie im Daimler AG Office V
# Find Yelp ID for Google ID: ChIJK4Qk6iDdmUcR0r1WsrOHCn8
# ...restaurant Yuícery & chicco di caffè - Daimler AG Office V at 48.7247568, 9.1223696
# No match found for Google name: Yuícery & chicco di caffè - Daimler AG Office V
# Find Yelp ID for Google ID: ChIJFdlNoeLcmUcRrxoHZjK0png
# ...restaurant (Tagesbar da Domenico) at 48.7202981, 9.1269198
# No match found for Google name: (Tagesbar da Domenico)
# Find Yelp ID for Google ID: ChIJe9T87FPdmUcRyMuFo5EfbNs
# ...restaurant La Pizzetta Lieferservice at 48.7203248, 9.1268029
# No match found for Google name: La Pizzetta Lieferservice
# Find Yelp ID for Google ID: ChIJKYPXyQLdmUcRbtlRrJSjGBw
# ...restaurant Restaurant Mesogios at 48.7189796, 9.1247128
# No match found for Google name: Restaurant Mesogios
# Find Yelp ID for Google ID: ChIJ0SO7gFbcmUcRk_WK_y_iPr4
# ...restaurant Pullman Hotel Stuttgart Fontana at 48.72654720000001, 9.111341500000002
# ...Yelp ID: mxuwZcFe7rUC7doPDoBPPQ
# Find Yelp ID for Google ID: ChIJcW-tFVfcmUcRG-RQ7uB1Kao
# ...restaurant Subway at 48.7300317, 9.111397199999999
# ...Yelp ID: utC3jdQ4H2ftGxrETDAu4Q
# Find Yelp ID for Google ID: ChIJXWn_lavdmUcRYxpoxu_-qGc
# ...restaurant Eisenmann at 48.7181378, 9.1073969
# ...Yelp ID: Ic1C6ftyyzT2tbMUTQ0LBg
# Find Yelp ID for Google ID: ChIJIa1ImVPcmUcRv1tqhv1v3z4
# ...restaurant Aral at 48.724718, 9.106641000000002
# ...Yelp ID: jyWkPwUrZZ9e_BZv-vS2-g
# Find Yelp ID for Google ID: ChIJdwOQm__cmUcR1P78jnz4SUY
# ...restaurant NLV-Ristorante/Pizzeria at 48.72308829999999, 9.114709699999997
# No match found for Google name: NLV-Ristorante/Pizzeria
# Find Yelp ID for Google ID: ChIJ05gcvlfcmUcRms3MMadyFEo
# ...restaurant Maulwurf Kneipe und Bar at 48.72988609999999, 9.1140115
# No match found for Google name: Maulwurf Kneipe und Bar
# Find Yelp ID for Google ID: ChIJXWQC91XcmUcR5QcoEu-pvPM
# ...restaurant Naherholungsgebiet Lausterer/Sabitzer Gbr at 48.725425, 9.1142874
# No match found for Google name: Naherholungsgebiet Lausterer/Sabitzer Gbr
# Find Yelp ID for Google ID: ChIJdyOuFVfcmUcRzk3p5DNGxh4
# ...restaurant Holzkrug at 48.73002470000001, 9.111827100000001
# ...Yelp ID: 9HnbYJuWhDNRwoBpOVRQ3w
# Find Yelp ID for Google ID: ChIJYVE5SFXcmUcR5r7QVGakEQ0
# ...restaurant Restaurant Schwarzbach at 48.7218094, 9.1119671
# ...Yelp ID: dlkkHsyx-T_AvMnthycT4w
# Find Yelp ID for Google ID: ChIJ9YfvPf_cmUcRj4wf_Y7JVK0
# ...restaurant Ruppmannschänke at 48.724819, 9.116303
# ...Yelp ID: oH6Yx_xIzeEAqRCEqW1xVQ
# Find Yelp ID for Google ID: ChIJT-0vWqXdmUcR9GUgw95wXUg
# ...restaurant Gaumenschmaus Haenchen at 48.7255408, 9.1153619
# No match found for Google name: Gaumenschmaus Haenchen
# Find Yelp ID for Google ID: ChIJQ_llcT_dmUcRaMVlKZVyFGc
# ...restaurant Eat Happy at 48.7255281, 9.115077399999999
# ...Yelp ID: 9A-y0TWBKqqP5vsn_CwI3g
# Find Yelp ID for Google ID: ChIJVbdSbVbcmUcRy6S09AktYKs
# ...restaurant Wirtshaus Zum Alten Bahnhof at 48.7269424, 9.113395299999999
# ...Yelp ID: tHwp4CjJqUXEjJtpoLHjUQ
# Find Yelp ID for Google ID: ChIJ_fifqVfcmUcRTlXIw-4ZIr8
# ...restaurant Hoang Asia Imbiss at 48.7291915, 9.112757900000002
# ...Yelp ID: NiviplzqF1RtwLvYnL79fQ
# Find Yelp ID for Google ID: ChIJI4-pqVfcmUcRLMx4Us8X_bM
# ...restaurant Ivica Rezo Gaststättenbetriebe e.K. at 48.729249, 9.1127699
# No match found for Google name: Ivica Rezo Gaststättenbetriebe e.K.
# Find Yelp ID for Google ID: ChIJVVUVqFfcmUcRORZYWoSeYyg
# ...restaurant Gülnaz Döner & Pizza at 48.7293539, 9.112712499999997
# No match found for Google name: Gülnaz Döner & Pizza
# Find Yelp ID for Google ID: ChIJf_1x5AvdmUcRD8Jh7REi_RM
# ...restaurant Eat Happy at 48.72962030000001, 9.1118479
# ...Yelp ID: 9A-y0TWBKqqP5vsn_CwI3g
# Find Yelp ID for Google ID: ChIJB3Ey7FXcmUcRvQ2act8k2xk
# ...restaurant Aqua, Restaurant Bar und Lounge at 48.7251666, 9.1134439
# No match found for Google name: Aqua, Restaurant Bar und Lounge
# Find Yelp ID for Google ID: ChIJ0SO7gFbcmUcR91-ecxAdfhc
# ...restaurant FONTANA RESTAURANT at 48.7263747, 9.111349299999999
# ...Yelp ID: sj18RDxKq6n_JMYIJ8T4zg
# Find Yelp ID for Google ID: ChIJib05d3vdmUcRyllsVjiP2fU
# ...restaurant Der Nudelstrauss ,,Lé Bouquet dé Pates" at 48.7302606, 9.111054700000002
# No match found for Google name: Der Nudelstrauss ,,Lé Bouquet dé Pates"
# Find Yelp ID for Google ID: ChIJK50s8iTdmUcR9Hjv65X_XRg
# ...restaurant Vaihingen Ezom Kebap at 48.73006999999999, 9.1109175
# No match found for Google name: Vaihingen Ezom Kebap
# Find Yelp ID for Google ID: ChIJbQcAnFbcmUcRuFuO99i5Z6U
# ...restaurant Rolands Maultaschen Offene Kantine at 48.7269805, 9.110544299999999
# No match found for Google name: Rolands Maultaschen Offene Kantine
# Find Yelp ID for Google ID: ChIJGcWHeqzdmUcRLdgyk4KDhao
# ...restaurant Neuberths Gastwerk - Restaurant, Weinstube at 48.7186646, 9.105319399999997
# No match found for Google name: Neuberths Gastwerk - Restaurant, Weinstube
# Find Yelp ID for Google ID: ChIJ470y1TncmUcR7ud5npHyEHk
# ...restaurant Merakles at 48.73311330000001, 9.088442799999997
# No match found for Google name: Merakles
# Find Yelp ID for Google ID: ChIJAQDwNq3dmUcR9uaSgWcT4T4
# ...restaurant China Jiangsu at 48.72159769999999, 9.102349799999999
# No match found for Google name: China Jiangsu
# Find Yelp ID for Google ID: ChIJFRu3k6vdmUcR0K1KVG5ANno
# ...restaurant Roma Pizza at 48.7181451, 9.106827699999998
# ...Yelp ID: x3ApdQIapzf4Zcfsv-0ZBg
# Find Yelp ID for Google ID: ChIJF1-R6EjcmUcRDqFi-dTrtS4
# ...restaurant Aral at 48.7308696, 9.0952231
# ...Yelp ID: jyWkPwUrZZ9e_BZv-vS2-g
# Find Yelp ID for Google ID: ChIJ1_6psa3dmUcRvJJssPmQcLA
# ...restaurant Inn Waldhorn at 48.7186658, 9.102313200000001
# No match found for Google name: Inn Waldhorn
# Find Yelp ID for Google ID: ChIJVShhzVDcmUcRvSewocsjNoQ
# ...restaurant Daily Burger at 48.72966279999999, 9.1094622
# ...Yelp ID: uihTyORM9VXHrVA4vKelhg

# %%
# Write to CSV file and Excel file
df = pd.DataFrame(yelp_ids_based_on_google, columns=['yelp_id'])
df.to_csv('yelp_ids_based_on_google_search.csv')
df.to_excel('yelp_ids_based_on_google_search.xlsx')

# %% [markdown]
# ### Download Yelp IDs based on Multiple Yelp searches

# %% [markdown]
# Only ~420 of the restaurants found via Google Places could be matched to a Yelp ID based on name and geolocation search. This is probably the case when the names at Google Places vs. Yelp differ too much (even though the Yelp API does not seem to require an exact match), or when the geolocations differ too much. However, we saw the results changing across multiple executions (cf. https://github.com/Yelp/yelp-fusion/issues/197), and the number of matches ranged between 408 and 430.
#
# So we need to supplement these matches with additional results, retrieved from Yelp directly.
#
# Even though the Yelp API would support to request up to 1000 results around one location (instead 3x20 ), we prefer a grid-based search around multiple search centers (similar as we did with Google Places earlier), which is supposed to provide a higher coverage.

# %%
# Define inner and outer quadrangle within we want to search as well as the appropriate step width.
# For the inner quardrangle, we define a smaller step width. 

step = -0.029 # ~2km
smaller_step = step / 2

# Stuttgart area
start_lat = 48.85
end_lat = 48.66
start_long= 9.38
end_long = 8.95

# Stuttgart city
start_lat_city = 48.83
end_lat_city = 48.72
start_long_city = 9.25
end_long_city = 9.10

# %%
# Show search centers as markers on Google Maps

maps.configure(PLACES_API_KEY)
fig = maps.figure()

# Draw red markers for the wider area of Stuttgart
marker_locations=[]
for i in np.arange(start_lat, end_lat, step):
    for j in np.arange(start_long, end_long, step):
        # draw markers only if i and j is not within the city area
        if ((i > start_lat_city) | (i < end_lat_city) | (j > start_long_city) | (j < end_long_city)):
            marker_locations.append((i, j))
            
print("Number of red markers: {}".format(len(marker_locations)))   
markers_red = maps.symbol_layer(marker_locations, fill_color='blue', stroke_color='blue')
fig.add_layer(markers_red)

# Draw blue markers for the city area of Stuttgart
marker_locations=[]
for i in np.arange(start_lat_city, end_lat_city, smaller_step):
    for j in np.arange(start_long_city, end_long_city, smaller_step):
        marker_locations.append((i, j))

print("Number of blue markers: {}".format(len(marker_locations)))   
markers_blue = maps.symbol_layer(marker_locations, fill_color='purple', stroke_color='purple')
fig.add_layer(markers_blue)

fig
# Out:
# Number of red markers: 85
# Number of blue markers: 88
# Figure(layout=FigureLayout(height='420px'))

# %%
yelp_ids = []
yelp_names = []
yelp_lats = []
yelp_lngs = []
for marker in marker_locations:
    yelp_result = yelp_api.search_query(
        term='restaurant', latitude=marker[0], longitude=marker[1], radius=1500, limit=50)
    for i in range(len(yelp_result['businesses'])):
        yelp_id = yelp_result['businesses'][i]['id']
        name = yelp_result['businesses'][i]['name']
        lat = yelp_result['businesses'][i]['coordinates']['latitude']
        lng = yelp_result['businesses'][i]['coordinates']['longitude']
        yelp_ids.append(yelp_id)
        yelp_names.append(name)
        yelp_lats.append(lat)
        yelp_lngs.append(lng)
yelp_results.append(yelp_result)

# %%
assert(len(yelp_names) == len(yelp_ids) & len(yelp_ids) == len(yelp_lats) & len(yelp_lats) == len(yelp_lngs))

# %%
# Build DataFrame
d = {'yelp_id':yelp_ids, 'name':yelp_names, 'latitude': yelp_lats, 'longitude':yelp_lngs}
yelp_restaurants = pd.DataFrame(d)
yelp_restaurants.head()
# Out:
#                   yelp_id                                         name  \
# 0  -k0Ksk_FSzQAiKU6tdjayg               Restaurant Tsv Steinhaldenfeld
# 1  5djuZfIkqf1ykQGbpWESrg                                       Stadio
# 2  R93PaCrS4qai9u1uiiHPMw  Restaurant "La Perla" im Schießsportzentrum
# 3  3e_HLr7Qu6Azg7Hp6EK3aw                                Rems La Pizza
# 4  kscS_CV9KX-j1zdfvBu7mQ                                Il Carrettino
#
#     latitude  longitude
# 0  48.829740   9.240350
# 1  48.831900   9.252310
# 2  48.833358   9.249487
# 3  48.840622   9.267763
# 4  48.833700   9.264480

# %%
yelp_restaurants['yelp_id'].nunique()
# Out:
# 823

# %%
# De-dupliacte
yelp_restaurants = yelp_restaurants.drop_duplicates()

# %% [markdown]
# #### Yelp IDs found via Matching Google results vs. Yelp IDs found via Yelp directly

# %% [markdown]
# `yelp_ids_based_on_google` (IDs based on Google search):
#  * Based on the list of Google IDs, obtained by multiple Google Places Nearby Searches with varying search centers, returning 3x20 results each
#  * Based on the Google ID, lookup the Google name and try to find a match at Yelp
#  * For 1333 Google restaurants, only 430 matches could be identified, probalby because of name or geolocation mismatch between Yelp and Google (e.g. "Eat Drink Man Woman" vs. "Gasthaus Eat Drink Man Woman")
#
# `yelp_ids_based_on_yelp` (IDs based on Yelp search):
# * Based on multiple Yelp Search Queries with 50 results each, using the same search grid as earlier for the Google search
# * 823 results after de-duplication
#
# `yelp_ids_based_on_google` - `yelp_ids_based_on_yelp`:
# * 97 restaurants that are in `yelp_ids_based_on_google`, but not in `yelp_ids_based_on_yelp` .
# * Restaurants that were originally found via Google grid search, then mapped to the Yelp equivalents, but are not found via Yelp grid search
#
# `yelp_ids_based_on_yelp` - `yelp_ids_based_on_google`:
# * 498 restaurants that are in `yelp_ids_based_on_yelp`, but not in `yelp_ids_based_on_google`
# * Restaurants that are found via Yelp grid search, but not included in the Yelp equivalents for our previous Google search
# * Mostly due to 'name mismatch' between Google name and Yelp name
#
# ==> We continue with a merged set (`yelp_ids_based_on_google` + `yelp_ids_based_on_yelp`) to avoid missing any relevant restaurant, wether it comes from Google or from Yelp. This gives us **823 + 97 = 920 restaurants in the area of Stuttgart**.

# %%
yelp_set = set(yelp_ids_based_on_yelp)
google_set = set(yelp_ids_based_on_google)
print(len(yelp_set), len(google_set))
# Out:
# 823 422

# %%
# IDs that are included in Yelp-based grid search, but not in Google-based grid search
# This includes also the name mismatch cases
yelp_minus_google = yelp_set.difference(google_set)
len(yelp_minus_google)
# Out:
# 498

# %%
# IDs that are included in Google-based search, but not in Yelp based search
google_minus_yelp = google_set.difference(yelp_set)
len(google_minus_yelp)
# Out:
# 97

# %%
print("IDs contained in yelp-based but not in google-based search (mostly due to name mismatch)")
for id in yelp_minus_google:
    print(get_name(id))
# Out:
# IDs contained in yelp-based but not in google-based search
# The Gardener’s Nosh
# Ristorante Le Rose
# Bäckerhaus Veit Café
# Ristorante Pizzeria La Taverna da Enzo
# Weinwirtschaft | Weingut Franz Keller
# Zum Adler Gasthaus Weinstube
# ESV Rot-Weiss Vereinsgaststätte
# Restaurant Schmidener Eintracht
# Bäckerhaus Veit Café
# Mikail's Lunchbox
# Da Mamma Maria
# 1/1
# Yakiniku
# Due Stanze e Cucina
# Rhythms Bar & Kitchen
# Goldener Adler
# List
# Ristorante Russo Wine Food and Eventlocation
# Zum Becher
# Gasthof Riedsee
# Gasthaus zum Kreuz
# Dam Dam Hot Pizza
# SEN Asia Soul Kitchen
# Cannstatter Tor
# Gaststätte Post
# Fischlounge
# Geiler
# Sattlerei
# Il Terrazzino
# Weinstube Kochenbas
# Gaststätte Trompetle
# Gravity
# Triple B
# Cafe & Bar Nion
# Taverna Sultan Saray
# ALATURKA - Das Stuttgarter Original
# Kwan Kao
# Noir Cuisine&Bar
# [m]eatery
# Campioni
# Christo's Stube
# Funfo's
# Bahtti Super Pizza Service
# Weinhalle 1896
# Cavallino Spaghettaro
# Diogenes Taverne
# Flori & Palma
# Vereinsgaststätte Himmerreich
# Los Locos Latinos
# Da Micci
# Restaurant LE
# le tonneau
# Gaststätte Schlesinger
# Eis-Cafe-Mario
# Wok's Tay Ho
# Flo
# Insel Café
# La Taverna Da Pagano
# Perbacco
# Delicious - Christophstraße
# Gaststätte Ackermanns
# Little Italy
# Pukki's
# Alacati Beach Club Stuttgart
# Biergarten am Killesberg
# By-The-Way and to Go
# CBS-food,drinks&more café bar
# Löwen
# Restaurant Do
# La Strada
# Café Gant
# CBC
# CaféHaus Veit
# Timi's Grill
# Kronprinz
# L.A. Signorina
# Untere Körschmühle
# Gaststätte Klosterkeller
# Hotel & Restaurant Römerhof
# Santa Lucia
# Palm Beach
# Gasthaus Waldhorn
# Vital Lunch
# Angelo's Pizza-Taxi
# Bella Napoli
# Attimi
# Café Siegel
# Gourmet Casino
# Sommerrain
# Rechberg
# Metzgerei Häfele
# S'Häfele
# König Kebap
# Weinwirtschaft
# Gourmetrestaurant Maestro
# Eleven
# Thai Viet
# Tiffany Cafe Bar
# Amore
# Serhat Döner Kebap
# Kim's So
# Food Court
# Beykebab
# Piroschka Konditorei & Café
# Gaststätte Maulwurf
# Zum Schluckspecht
# Gast
# Restaurant Dachswaldblick
# Kosta's Restaurant
# San's
# Café Blüte
# Palast der Republik
# Il Carrettino da Antonio
# Neuer Imbiss
# Tshito-Gwrito
# Aviatik
# Café Justus
# Simit house Cafè
# KFC
# Finch
# Weinstube Klink
# Das Backparadies
# Schwoabetöpfle
# Drei Mohren
# Al Vecchio Mulino
# Restaurant Kemnater Hof
# Fresko
# Aladin - Pizza Kebab & Grill
# Trattoria da Giovanni Ri
# Sonnenbesen
# Zum Ackerbürger
# Asia Wok - Sushi-China-Thai Imbiss
# NEUE DÖNASTIE
# Festzeltbetriebe Göckelesmaier
# Pizza Express
# Olümp
# Hexle
# Nudelbox
# da Maria
# Weinstube Klösterle
# Mozart 3
# Gaststätte Kanonenbäck
# Gaststätte Stöckachstube
# Restaurant Granada
# Yuícery
# Burger King
# La Stella
# Yaz
# Stoighofbesen
# Tokio Dining
# Gaststätte Schwanen
# Tabano
# Brenner
# Sehne Backwaren
# Glora Kaffeehaus-Das Kaffee aus Stuttgart- Rösterei Manufaktur
# Bo's Burger & Bar
# Möhringer
# Kantinchen
# Roseneck da Linda
# Gaststätte Alte Hupe
# Shira Restoran Kurdisch-Türkische Spezialitäten
# Da Domenico
# Zum Golf
# Sahara Food
# Vfl bei Stogi
# Oblomow
# Waldheim Heimberg
# Ramen 8
# Round House Burger
# Park-Restaurant
# Ampulle
# Allgäuer Stüble
# Carls Brauhaus
# Bäckerhaus Veit Café
# Pizzeria Trattoria Regenbogen
# Grand Cafe Santin
# Ali Baba
# Gaststätte Hondler
# Café Olé
# Mediterraneo
# Bei Kosta
# Weinstube Vetter
# Anatolia
# The Legend of Floating Market
# Waldheim Restaurant
# Restaurant im Mercedes-Benz Museum
# Zom Baecka Dais
# Kashmir
# River Kwai
# Wisag Kantine
# Gaststätte Lamm
# Oh my Burger
# Huong Viet
# Henpoint
# Kickers Clubrestaurant
# Mauritius
# Seven Billard Café
# Republic
# La Grazia
# Five Guys
# Besenwirtschaft Gohl - bei d'r Elsbeth
# d'r Knaudl
# Teehaus im Weißenburgpark
# Turn- und Sportverein Weilimdorf 1948 e.V.
# Namaste India
# Ristorante Elisa Alte Post
# Gaststätte Ochsen
# Biergarten im Schlossgarten
# Gasthaus zur Linde
# Messina
# Rembrandt Stuben
# Turnerbund Gaisburg 1886 e.V.
# Café am Markt
# Gaststätte Schwanen
# Osmali Tulumbacisi
# Stöckle
# Patrick's Stop
# Trattoria da Peppe
# Enoteca
# Pizzeria Adler
# Nem
# Serkan Genc Gaststätte Divan 2
# Scharfes Eck
# Viet Quan - Asia Gourmet
# Biergarten Klingenbach
# pane e vino
# Pizzeria Am Wildwechsel
# QQ Fusion
# Harambe Afrika
# Bistro & Cafe Bürkle Im Mineralbad Cannstatt
# Landschloss Korntal
# Schnitzelkönig
# Hans im Glück
# Taverne Odyssia
# Kirchtal
# Yorma's
# Restaurant Lindenstüble
# Cafe Casa
# Rolands Maultaschen
# Hot Asia
# Burger House
# Gaumenschmaus Hähnchengrill
# Imbiss Bagdad
# EZOM KEBAP
# Dionyssos Im Hirsch
# Rote Kapelle
# Weinstube zur Traube
# Conditorei
# Mikomi
# Feuerbacher
# Restaurant zum Duy
# Ehli Keyf Shisha Cafe
# WO
# Taverna
# Rems La Pizza
# Senzanome
# Löwenstube
# Lokanta
# Metzgerei Häfele
# L'Osteria
# mokkam
# Snack Station 33
# Quan-An
# Herbert'z Espressobar
# Divan
# Trattoria Piloni
# Köfteci Tuncay
# Italiani
# Nouvel
# King's Palace
# Imbiss Dinkelacker
# Unser Imbiß
# Geschlossen Restaurant Vinayaga
# Die scharfe Currywurst
# Besen66
# Kaminrestaurant
# Restaurant mo.town
# Ristorante Sardegna
# Durgun Pizza Kebab
# Amani
# Abbo‘s Döner & Grill
# Adana Sofrasi
# Antep Haus
# Naturfreundehaus Vaihingen
# Luftbad
# Bäckerei und Konditorei Friedrich Übele
# Speedy's Pizzaservice
# Restaurant Zeppelino'S
# Restaurant A.C. Hotel Hoferer
# Kupferkessel
# Café Lang
# Alter Hasen
# Safran
# Fußballverein Germania Degerloch e.V.
# Genc Kebap
# Restaurant Amazonica
# Gasthaus Krone
# Brunnenwirt
# Caffebar Hölderlin
# Danziger Stüble
# Am Fasanenwald
# QQ Sushi Lounge
# Cantina
# Patch Gardens
# Ristorante Projectum
# Kwan Kao
# Zeppelin Stüble
# Voglia di Pizza
# Bella Vista
# Laxmy
# Shima
# Nga Imbiss
# Backstube Back & Snack
# Fossil
# Tarte & Törtchen
# Cafeteria  Merz-Akademie
# Wiener Kaffeehaus
# Restaurant Weissenhof
# è la Vita
# Tafelberg
# Cuu Long
# L'angolino
# Asia Via He
# Lindenhof - Restaurant
# Waldheim Raichberg
# Lotusblume
# Cannstatter Kebap Haus
# Mauritius
# Cafebar Auszeit
# Vereinsheim Gartenfreunde Heslach
# Döner Imbiss im Hak Verdi Supermarkt
# Hell's Kitchen Bar & Grill
# 87 Barbecue & Bar
# Gasthaus Rössle
# Heuss am Killesberg
# Tagesbar
# The Burger Republic
# Oishi Sushi
# Jakova Burger
# Seyffer's
# villa rustica
# Fischhalle Austernbar
# Burreatos
# Arzum
# NLV Pizzeria
# Kleinschmeckerei
# Restaurant Stadthotel Weinsberg
# Dedemoğlu
# Saray Kebap 2
# peperoncino
# Fontana
# Telekom Kantine
# Da Domenico
# Hasen
# Mögle
# Injeera
# Shabu Shabu
# DLRG Gaststätte
# Stern Kebap
# Plieninger Most- und Weinbesen
# Restaurant Zillertal
# Persian Restaurant
# HendlBurg
# Asia Imbiss Hop Sing
# Rosenau - Lokalität & Bühne
# Gaststätte Schützenhaus - Dimi
# Reyerhof-Bistro
# Ambiente
# City Imbiss
# dr' Schbruchbeidl
# Thang Long
# Pizza Pasta Taxi
# Balino Belvedere
# Goldener Drachen
# Höhencafe am Killesberg
# Heslacher Weinstube
# Stallbesen
# Day & Night Pizza
# Il Pomodoro
# Moulu
# Alpenpizzeria
# Vereinsgaststätte der Gartenfreunde Grenzäcker
# Lek's
# Anatolien Kebap Haus
# Naherholungsgebiet
# La Rusticana
# MairDumont Kantine Eurest
# Dedemoglu
# La Medina
# Esszimmer
# Ü das Café
# Max&Moritz 2
# Restaurant Waldheim
# Viertel
# nica Vereinsgaststätte TSV 07
# Harmonie
# RED BLACK BURGER
# Alte Post
# Krone - Trattoria
# Vaihinger Pizza Kebaphaus
# Keyaki
# Weitmann's Waldhaus
# PS! Theatergastronomie
# SchwabenSpeisen
# Reishaus
# Chefs Imbiss
# Cafe Dolce
# Poushe Strudelhaus Stuttgart
# Pizzeria Salento
# Noodle Box
# Besen 66
# Speiserestaurant der SpVgg Cannstatt
# Milchbar Killesberg
# Stern Kebap
# Bei Poula
# Das Wollcafé
# Cantina dei Dogi
# Wirtshaus Zur alten Schmiede
# Moonlight Nachtlieferservice Stuttgart
# Meze Meze
# CQ Flavour
# Thai-Palast
# Giovanni Sperenza
# Talwiesenstuben
# Il Carrettino
# The Green Stream
# City Grill
# Gaststätte Linde
# Retsinadiko
# Feuerbacher Wichtel
# Burger Deluxe
# Gasthaus Bären
# Ruben's
# Galerie
# Thios Inn
# Asv Athletik-Sport-Verein Botnang von 1898 e.V.
# Mom's Cooking Greek
# Nachtschicht
# Restaurant im türkisch-islamischen Zentrum
# Café Bar Bliss
# El Seco
# Palazzo
# Super Jami
# Distelfarm
# Cafe Elflein
# Hegel Eins
# Namaste India
# Eiscafé Canaletto
# YAFA
# Tsimpo
# Verein Waldheim Zuffenhausen 1911 e.V.
# Hans Im Glück
# Topfgucker
# POP's
# Chicken Tom
# Wirtsstube Emilie
# Pizza Amigo
# Gablenberger Pizza & Kebaphaus
# Restaurant Filoxenia
# ristorante musica é
# Wiesenstüble
# Vier Burgen
# Aslan Kebab
# Hirsch Gehrung
# Merci
# Eat Drink Man Woman
# La bonne Baguette
# Zum Spätzleschwob
# Sen Viet
# Chinese Wok Lieferservice
# Cantuccio
# Café Hoffeld
# Red Grill
# pizzabar
# Cafe Kaiserbau
# Restaurant Fässle
# Gasthaus Johannesgarten
# La Rinascente
# Pizzeria Ristorante Puglia
# Sushi.Wrap
# Zur Weinsteige
# Alte Dorfschule
# Boxenstopp
# Thai Orchidee
# Gaststätte Krone
# Siegel
# Asia World
# Weinstube Kachelofen
# Noodle 1 Dining
# Sichuan
# Can Döner
# Sakristei
# Café MuseO
# Asia Viet Long
# Il Pomodoro
# Hans Im Glück
# Taverna Janni & Güllo
# Cafe Tratsch

# %%
print("IDs contained in google-based but not in yelp-based search")
for id in google_minus_yelp:
    print(get_name(id))
# Out:
# IDs contained in google-based but not in yelp-based search
# Tokyo Sushi
# Sultan Saray
# Bocca Buona
# Hotel Schmidener Eintracht
# Cafe Le Theatre
# Hotel Hirsch
# Ristorante Positano
# PAULANER am alten Postplatz
# Gaststätte Trollinger
# Arcotel Camino
# Burger King
# Schnauferl Grill
# Burger House
# Pizzeria Da Cesare
# Le Cassoulet
# Sultan Saray
# Ebony
# Aral
# La Bruschetta
# Amici
# Art Sushi
# Oggi
# Icebreaker Bar im Hotel Pullman Fontana
# Indian Palace
# Hotalo
# Pizza Fiesta
# Ristorante La Piazza
# Mauritius
# Da Noi Due
# Aral
# JET
# Logo - Rotisserie
# La Commedia
# Enchilada
# Aral Tankstelle
# Da Franco
# Ceylonas
# Spielbank Stuttgart
# Mezzogiorno
# SI-SUITES
# Alte Kanzlei
# Hotel Neuwirtshaus
# Sausalitos
# Bella Pizza Service
# Eberhard Braun - Gourmetcook - Kochveranstaltungen
# Claus
# Akzent Hotel Möhringer Hof
# 5
# The Dubliner
# Indian Shop
# 1893 - Das VfB Clubrestaurant
# DORMERO Hotel Stuttgart
# Im Eimer
# Laurita Pizza Service
# Früchtle vom Schmidener Feld
# Die Palette
# Thai Corner
# China-Imbiss-Panda
# Weber
# Pullman Stuttgart Fontana
# Cafe Monroe's
# Sakura
# Laguna
# Nordsee
# Zur Schreinerei
# Classic Rock Cafe
# Aral
# Ristorante Girasole
# Udo-Snack
# Hotel Royal
# Bertazzoni
# Makamba
# Aral
# Die Metzgerei
# Lindenhof - Hotel
# Naturgut am Hölderlinplatz
# Top Tennis
# Der Zauberlehrling
# Origami
# KFC
# TinTin
# Weinstube Zaiß
# Max-Eyth-See
# Antonios Pizza Taxi/Bar
# Besenwirtschaft Krug
# Hüftengold
# Eisenmann
# Tiffany Thaistyle
# Trattoria Santa Lucia
# Biddy Early's
# Römerhof
# Hotel Ochsen
# Ulmers Besenwirtschaft
# Andalucia-Casamuu
# McDonald's
# Bonnie & Clyde
# daras pizzaservice

# %%
def get_name(yelp_id):
    yelp_restaurant = yelp_api.business_query(id=yelp_id)
    return yelp_restaurant['name']

# %%
# Write IDs from Yelp-based search to file
df = pd.DataFrame(yelp_ids_based_on_yelp, columns=['yelp_id'])
df.to_csv('yelp_ids_based_on_yelp_search.csv', index=False)
df.to_excel('yelp_ids_based_on_yelp_search.xlsx', index=False)

# %%
# Save merged IDs from Google and Yelp-based search 
df = pd.DataFrame(list(merged_ids), columns=['yelp_id'])
df.to_csv('yelp_ids.csv', index=False)
df.to_excel('yelp_ids.xlsx', index=False)

# %% [markdown]
# ### Enrich merged IDs with detail information

# %% [markdown]
# We now have a list of ~820 Yelp IDs, retrieved either by matching the Google Places to Yelp Businesses, or by doing Yelp searches directly. For these IDs, we need to gather the required information (mostly from Yelp). We perform the following steps:
# - For each Yelp ID, make a Yelp business request and enrich the given ID with detail information (such as name, categories, geolocations).
# - For each Yelp ID, find the corresponding Google ID from Google Places. This is done with a Google Places find_place search based on Yelp name and location. For every Yelp ID, the corresponding Google ID can be found.

# %%
# Read in restaurant IDs.
df_yelp_ids = pd.read_csv('yelp_ids.csv')

# %%
# For each Yelp ID, get detail information from Yelp

id_list = []
name_list = []
is_closed_list = []
categories_list = []
price_list = []
rating_list = []
review_count_list = []
photos_list = []
address_list = []
lat_list = []
lng_list = []
for yelp_id in df_yelp_ids['yelp_id'].values:
    restaurant = yelp_api.business_query(id=yelp_id)
    name = restaurant['name']
    is_closed = restaurant['is_closed']
    categories = restaurant['categories']
    categories_unstacked = []
    for c in categories:
        categories_unstacked.append(c['title'])
    if 'price' in restaurant:
        price_level = restaurant['price']
    else:
        price_level = ''
    rating = restaurant['rating']
    review_count = restaurant['review_count']
    if 'photos' in restaurant:
        photo_urls = restaurant['photos']
    else: photo_urls = ''
    address = restaurant['location']['display_address']
    lat = restaurant['coordinates']['latitude']
    lng = restaurant['coordinates']['longitude']
    # Append everything to the lists
    id_list.append(yelp_id)
    name_list.append(name)
    address_list.append(address)
    is_closed_list.append(is_closed)
    categories_list.append(categories_unstacked)
    price_list.append(price_level)
    rating_list.append(rating)
    review_count_list.append(review_count)
    photos_list.append(photo_urls)
    lat_list.append(lat)
    lng_list.append(lng)
    
assert(len(id_list) == len(name_list) & len(name_list) == len(address_list) & len(address_list) == len(is_closed_list)
       & len(is_closed_list) == len(categories_list) & len(categories_list) == len(price_list) & 
       len(price_list) == len(rating_list) & len(rating_list) == len(review_count_list) & 
       len(review_count_list) == len(photos_list) & len(photos_list) == len(lat_list) & 
       len(lat_list) == len(lng_list))

# %%
d = {
    'yelp_id' : id_list,
    'yelp_name' : name_list,
    'address' : address_list, 
    'is_closed' : is_closed_list,
    'categories' : categories_list,
    'price_level' : price_list,
    'avg_rating' : rating_list,
    'review_count' : review_count_list,
    'photo_urls' : photos_list,
    'latitude' : lat_list, 
    'longitude' : lng_list
}

df_yelp = pd.DataFrame(d)

# %%
#Filter out all restaurants that are  permanently closed -> before 920, afterwards 915
df_yelp.drop(df_yelp[df_yelp['is_closed']==True].index, inplace=True)

# %%
# Write details DataFrame to file
#df_yelp.to_csv('yelp_restaurants.csv', index=False)
#df_yelp.to_excel('yelp_restaurants.xlsx', index=False)

# %%
# For each Yelp ID, find the corresponding Google ID
# Do so by first looking up the Yelp name, then make a Google Places find_place search based on Yelp name and location

google_ids = []
google_names = []
yelp_name_list = df_yelp['yelp_name'].values

for yelp_name in yelp_name_list:
    google_restaurant = gmaps.find_place(
        input=yelp_name, input_type='textquery', 
        location_bias='point:' + str(lat_hbf) + ', ' + str(lng_hbf), 
        fields=['place_id', 'name'],
        language='de')
    print(yelp_name)
    if (google_restaurant['candidates']):
        google_id = google_restaurant['candidates'][0]['place_id']
        google_name = google_restaurant['candidates'][0]['name']
        print('...OK')
    else:
        google_id = ''
        google_name = ''
        print('...not found')
    google_ids.append(google_id)
    google_names.append(google_name)
        
assert(len(yelp_name_list) == len(google_ids) & len(google_ids) == len(google_names))
# Out:
# Bäckerhaus Veit Café
# ...OK
# Prince of India
# ...OK
# Bocca Buona
# ...OK
# Weinwirtschaft | Weingut Franz Keller
# ...OK
# Zum Adler Gasthaus Weinstube
# ...OK
# ESV Rot-Weiss Vereinsgaststätte
# ...OK
# Restaurant Schmidener Eintracht
# ...OK
# Bäckerhaus Veit Café
# ...OK
# Mikail's Lunchbox
# ...OK
# India House
# ...OK
# Da Mamma Maria
# ...OK
# Ruppmannschänke
# ...OK
# Schnauferl Grill
# ...OK
# Goldener Adler
# ...OK
# List
# ...OK
# Taverne Diogenes
# ...OK
# Wienerwald
# ...OK
# Joe Peña's
# ...OK
# Tschechen & Söhne
# ...OK
# Dam Dam Hot Pizza
# ...OK
# SEN Asia Soul Kitchen
# ...OK
# Cannstatter Tor
# ...OK
# Gaststätte Post
# ...OK
# Kebap Stern
# ...OK
# Geiler
# ...OK
# Art Sushi
# ...OK
# Wirtshaus zum Alten Bahnhof
# ...OK
# Don Giovanni Ristorante Pizzeria
# ...OK
# Cafe & Bar Nion
# ...OK
# ALATURKA - Das Stuttgarter Original
# ...OK
# Kwan Kao
# ...OK
# Gasthof Franziska
# ...OK
# Akeno
# ...OK
# Noir Cuisine&Bar
# ...OK
# Ristorante La Piazza
# ...OK
# Christo's Stube
# ...OK
# Bahtti Super Pizza Service
# ...OK
# Cavallino Spaghettaro
# ...OK
# Flori & Palma
# ...OK
# Vereinsgaststätte Himmerreich
# ...OK
# Restaurant LE
# ...OK
# le tonneau
# ...OK
# Flo
# ...OK
# No.70 Finest Burger & Salads
# ...OK
# Dang Asian Cooking
# ...OK
# I Love Sushi
# ...OK
# Restaurant Dionysos
# ...OK
# Delicious - Christophstraße
# ...OK
# Bauerles Besen
# ...OK
# Pukki's
# ...OK
# By-The-Way and to Go
# ...OK
# La Strada
# ...OK
# Café Gant
# ...OK
# Lúc Lác
# ...OK
# La Bruschetta
# ...OK
# Akzent Hotel Möhringer Hof
# ...OK
# DORMERO Hotel Stuttgart
# ...OK
# Im Eimer
# ...OK
# Restaurant Cortijo
# ...OK
# Timi's Grill
# ...OK
# L.A. Signorina
# ...OK
# Untere Körschmühle
# ...OK
# Gaststätte Klosterkeller
# ...OK
# City - Pizza & Kebap
# ...OK
# Hotel & Restaurant Römerhof
# ...OK
# Santa Lucia
# ...OK
# Palm Beach
# ...OK
# Leonhardts
# ...OK
# Pilum
# ...OK
# Vital Lunch
# ...OK
# Angelo's Pizza-Taxi
# ...OK
# Restaurant Rösch
# ...OK
# Café Siegel
# ...OK
# Sakura
# ...OK
# Stern Kepab
# ...OK
# Gourmet Casino
# ...OK
# Magic Pizza
# ...OK
# Metzgerei Häfele
# ...OK
# S'Häfele
# ...OK
# New Asia Imbiss
# ...OK
# Ristorante Girasole
# ...OK
# Tiffany Cafe Bar
# ...OK
# Amore
# ...OK
# Sushi-Le
# ...OK
# Beykebab
# ...OK
# Gaststätte Maulwurf
# ...OK
# Aspendos
# ...OK
# Kosta's Restaurant
# ...OK
# San's
# ...OK
# Tasca im Feui
# ...OK
# Café Blüte
# ...OK
# Il Carrettino da Antonio
# ...OK
# Neuer Imbiss
# ...OK
# Tshito-Gwrito
# ...OK
# Aviatik
# ...OK
# Russini
# ...OK
# Simit house Cafè
# ...OK
# KFC
# ...OK
# Schwoabetöpfle
# ...OK
# Nga Asia Bistro
# ...OK
# Eisenmann
# ...OK
# Fresko
# ...OK
# Aladin - Pizza Kebab & Grill
# ...OK
# Trattoria da Giovanni Ri
# ...OK
# Imbiss Inn
# ...OK
# Sonnenbesen
# ...OK
# Asia Wok - Sushi-China-Thai Imbiss
# ...OK
# Pizza Express
# ...OK
# Ha Long
# ...OK
# Olümp
# ...OK
# Nudelbox
# ...OK
# Weinstube Klösterle
# ...OK
# Mozart 3
# ...OK
# Lilavadee
# ...OK
# Asia Mai
# ...OK
# Bar Vicino
# ...OK
# Gaststätte Trollinger
# ...OK
# Gaststätte Schwanen
# ...OK
# Tabano
# ...OK
# Kelley Club
# ...OK
# Brenner
# ...OK
# Glora Kaffeehaus-Das Kaffee aus Stuttgart- Rösterei Manufaktur
# ...OK
# Bo's Burger & Bar
# ...OK
# Möhringer
# ...OK
# Sultan Saray
# ...OK
# Ebony
# ...OK
# Gaststätte Alte Hupe
# ...OK
# Gülnaz Kebap Haus
# ...OK
# Da-Capo
# ...OK
# Pavone Pizza-Service
# ...OK
# Ristorante Da Luisa
# ...OK
# Sahara Food
# ...OK
# Oblomow
# ...OK
# Waldheim Heimberg
# ...OK
# Ramen 8
# ...OK
# Round House Burger
# ...OK
# Park-Restaurant
# ...OK
# Ampulle
# ...OK
# Allgäuer Stüble
# ...OK
# Indian Palace
# ...OK
# Carls Brauhaus
# ...OK
# Pizzeria Trattoria Regenbogen
# ...OK
# Grand Cafe Santin
# ...OK
# Enchilada
# ...OK
# Pizzeria San Gennaro
# ...OK
# YAYA Sushi
# ...OK
# Waldheim Heslach
# ...OK
# Franca e Franco
# ...OK
# Goldoni
# ...OK
# SI-SUITES
# ...OK
# Weinstube Vetter
# ...OK
# Galão
# ...OK
# Anatolia
# ...OK
# Eberhard Braun - Gourmetcook - Kochveranstaltungen
# ...OK
# 5
# ...OK
# Restaurant Theater Friedenau
# ...OK
# Pizza Express by Donica
# ...OK
# Henpoint
# ...OK
# Mauritius
# ...OK
# Woody's
# ...OK
# Da Salvo
# ...OK
# Seven Billard Café
# ...OK
# La Villa
# ...OK
# Da Zi Anna
# ...OK
# Restaurant Alte Hofkammer
# ...OK
# Subway
# ...OK
# Besenwirtschaft Gohl - bei d'r Elsbeth
# ...OK
# Teehaus im Weißenburgpark
# ...OK
# Cafe Monroe's
# ...OK
# Holzkrug
# ...OK
# Laguna
# ...OK
# Asia Imbiss Le
# ...OK
# Gaststätte Schdäffele
# ...OK
# Messina
# ...OK
# Rembrandt Stuben
# ...OK
# New Shanghai Restaurant
# ...OK
# Osmali Tulumbacisi
# ...OK
# Stöckle
# ...OK
# Patrick's Stop
# ...OK
# Enoteca
# ...OK
# Pho à la Mama
# ...OK
# Nem
# ...OK
# Serkan Genc Gaststätte Divan 2
# ...OK
# Scharfes Eck
# ...OK
# Viet Quan - Asia Gourmet
# ...OK
# Pizzeria Am Wildwechsel
# ...OK
# Harambe Afrika
# ...OK
# Bistro & Cafe Bürkle Im Mineralbad Cannstatt
# ...OK
# Cafe am Rathaus
# ...OK
# Origami
# ...OK
# Hans im Glück
# ...OK
# Taverne Odyssia
# ...OK
# Yorma's
# ...OK
# Mandu
# ...OK
# Restaurant Lindenstüble
# ...OK
# Augustenstüble
# ...OK
# Hot Asia
# ...OK
# Gaumenschmaus Hähnchengrill
# ...OK
# Antonios Pizza Taxi/Bar
# ...OK
# Das Lehen
# ...OK
# Imbiss Bagdad
# ...OK
# Restaurant Neckarblick
# ...OK
# Dionyssos Im Hirsch
# ...OK
# Rote Kapelle
# ...OK
# Raman Restaurant
# ...OK
# Amadeus Restaurant & Bar
# ...OK
# Wangener Besahex
# ...OK
# Weinstube zur Traube
# ...OK
# Conditorei
# ...OK
# Asia-Wok
# ...OK
# Restaurant zum Duy
# ...OK
# daras pizzaservice
# ...OK
# Taverna
# ...OK
# Hotel Schmidener Eintracht
# ...OK
# Senzanome
# ...OK
# Löwenstube
# ...OK
# Lokanta
# ...OK
# Mon Petit Café
# ...OK
# Ristorante Rusticone
# ...OK
# L'Osteria
# ...OK
# Da Domenico
# ...OK
# Restaurant Kicho
# ...OK
# Burger House
# ...OK
# Herbert'z Espressobar
# ...OK
# Udo Snack
# ...OK
# Restaurant "La Perla" im Schießsportzentrum
# ...OK
# Divan
# ...OK
# Edo Sushi
# ...OK
# Trattoria Piloni
# ...OK
# Italiani
# ...OK
# Le Pastis
# ...OK
# Imbiss am Fernsehturm
# ...OK
# King's Palace
# ...OK
# Restaurant Alte Wache
# ...OK
# Unser Imbiß
# ...OK
# Die scharfe Currywurst
# ...OK
# Dong Kinh Gourmet
# ...OK
# Mozzarella Bar
# ...OK
# Maultaschenhäusle
# ...OK
# Hupperts
# ...OK
# Ristorante Centrale
# ...OK
# Abbo‘s Döner & Grill
# ...OK
# Naturfreundehaus Vaihingen
# ...OK
# Luftbad
# ...OK
# Speedy's Pizzaservice
# ...OK
# Restaurant Zeppelino'S
# ...OK
# China Palast
# ...OK
# Café Lang
# ...OK
# Fußballverein Germania Degerloch e.V.
# ...OK
# Genc Kebap
# ...OK
# YoSH
# ...OK
# Da Franco
# ...OK
# Brunnenwirt
# ...OK
# Danziger Stüble
# ...OK
# Baran Kebab
# ...OK
# Am Fasanenwald
# ...OK
# Cantina
# ...OK
# Kleinigkeit-Essen und Trinken
# ...OK
# Pier 51
# ...OK
# Patch Gardens
# ...OK
# Ristorante Projectum
# ...OK
# Kwan Kao
# ...OK
# Zeppelin Stüble
# ...OK
# Restaurant Wielandshöhe
# ...OK
# Bella Pizza Service
# ...OK
# Bella Vista
# ...OK
# Laxmy
# ...not found
# Claus
# ...OK
# Nga Imbiss
# ...OK
# Dlrg Vereinsheim Treffpunkt am See
# ...OK
# Braustube Schloßturm
# ...OK
# Fossil
# ...OK
# Cafeteria  Merz-Akademie
# ...OK
# Restaurant Weissenhof
# ...OK
# épicerie fine
# ...OK
# Stadio
# ...OK
# Tafelberg
# ...OK
# Cuu Long
# ...OK
# Pro Arte Mediterraneo
# ...OK
# Mikoto
# ...OK
# Mauritius
# ...OK
# Zur Schreinerei
# ...OK
# Döner Imbiss im Hak Verdi Supermarkt
# ...OK
# Pizzeria Vesuvio
# ...OK
# Letzte Instanz
# ...OK
# Pazzo Pizza
# ...OK
# Hell's Kitchen Bar & Grill
# ...not found
# Pizzeria Pizzico
# ...OK
# Gasthaus Rössle
# ...OK
# Heuss am Killesberg
# ...OK
# Bertazzoni
# ...OK
# Oishi Sushi
# ...OK
# Jakova Burger
# ...OK
# Makamba
# ...OK
# Pizzeria Da Luigi
# ...OK
# Momentos
# ...OK
# villa rustica
# ...OK
# Fischhalle Austernbar
# ...OK
# Lindenhof - Hotel
# ...OK
# Arzum
# ...OK
# Kleinschmeckerei
# ...OK
# Lin's Wok
# ...OK
# Burger King
# ...OK
# Restaurant Stadthotel Weinsberg
# ...OK
# Saray Kebap 2
# ...OK
# Fontana
# ...OK
# Dolce Vita
# ...OK
# Telekom Kantine
# ...OK
# Il Pomodoro
# ...OK
# Shabu Shabu
# ...OK
# Stern Kebap
# ...OK
# Bei Den Steins
# ...OK
# Besenwirtschaft Krug
# ...OK
# Tonis Pizza-Service Stuttgart Zazenhausen
# ...OK
# Biddy Early's
# ...OK
# Restaurant Zillertal
# ...OK
# HendlBurg
# ...OK
# Gaststätte Schützenhaus - Dimi
# ...OK
# Ambiente
# ...OK
# City Imbiss
# ...OK
# Pizza Pasta Taxi
# ...OK
# Goldener Drachen
# ...OK
# Weinstube Im Alten Haus
# ...OK
# Heslacher Weinstube
# ...OK
# Hot Pizza Corner Lieferservice
# ...OK
# Vaihinger Drive
# ...OK
# Paros
# ...OK
# Il Pomodoro
# ...OK
# Arcotel Camino
# ...OK
# Moulu
# ...OK
# Speiserei
# ...OK
# Burger King
# ...OK
# Taverna Olympos
# ...OK
# Alpenpizzeria
# ...OK
# Anatolien Kebap Haus
# ...OK
# Naherholungsgebiet
# ...OK
# La Rusticana
# ...OK
# Dedemoglu
# ...OK
# La Medina
# ...OK
# Aral
# ...OK
# Restaurant Waldheim
# ...OK
# nica Vereinsgaststätte TSV 07
# ...OK
# Krone - Trattoria
# ...OK
# Takeshii's
# ...OK
# Vaihinger Pizza Kebaphaus
# ...OK
# Keyaki
# ...OK
# Weitmann's Waldhaus
# ...OK
# Reishaus
# ...OK
# Chefs Imbiss
# ...OK
# Cafe Dolce
# ...OK
# Poushe Strudelhaus Stuttgart
# ...OK
# Hoang Asia Imbiss
# ...OK
# Besen 66
# ...OK
# Speisekammer West
# ...OK
# Aral
# ...OK
# Lumen
# ...OK
# Logo - Rotisserie
# ...OK
# Stern Kebap
# ...OK
# Haus am See
# ...OK
# Naturfreundehaus Steinbergle
# ...OK
# Das Wollcafé
# ...OK
# Wirtshaus Zur alten Schmiede
# ...OK
# Moonlight Nachtlieferservice Stuttgart
# ...OK
# Waldheim Stuttgart Clara-Zetkin-Haus
# ...OK
# Ceylonas
# ...OK
# CQ Flavour
# ...OK
# Thai-Palast
# ...OK
# Giovanni Sperenza
# ...OK
# Talwiesenstuben
# ...OK
# Il Carrettino
# ...OK
# Zum Heurigen
# ...OK
# Nannina
# ...OK
# Das Reiskorn
# ...OK
# Feuerbacher Wichtel
# ...OK
# Indian Shop
# ...OK
# Hallo Emil
# ...OK
# Brauereigaststätte Dinkelacker
# ...OK
# Weinstube Am Stadtgraben
# ...OK
# Ruben's
# ...OK
# Galerie
# ...OK
# Buschpilot
# ...OK
# Die Palette
# ...OK
# Nachtschicht
# ...OK
# McDonald's
# ...OK
# Christophorus
# ...OK
# SGU Gaststätte Delphi
# ...OK
# Cafe Wahnsinn
# ...OK
# El Seco
# ...OK
# Palazzo
# ...OK
# QQ-Sushi Lounge
# ...OK
# Distelfarm
# ...OK
# Sultan Saray
# ...OK
# Hegel Eins
# ...OK
# Weinstube Viertelesschlotzer
# ...OK
# Pizza & Pasta - San Marco
# ...OK
# Ristorante La Scala
# ...OK
# IL Cappuccino
# ...OK
# POP's
# ...OK
# Chicken Tom
# ...OK
# Classic Rock Cafe
# ...OK
# Kursaal Cannstatt
# ...OK
# Weinstube Träuble
# ...OK
# Aral
# ...OK
# Restaurant Filoxenia
# ...OK
# Chito Gvrito
# ...OK
# Der Foehrich
# ...OK
# Vier Burgen
# ...OK
# Aslan Kebab
# ...OK
# Restaurant Ochsen
# ...OK
# Hirsch Gehrung
# ...OK
# Merci
# ...OK
# Udo-Snack
# ...OK
# Zum Spätzleschwob
# ...OK
# Sen Viet
# ...OK
# Red Grill
# ...OK
# Der Zauberlehrling
# ...OK
# pizzabar
# ...OK
# Piri Reis Restaurant & Cafe
# ...OK
# Taverne Saloniki
# ...OK
# KFC
# ...OK
# Imbiss Aronda
# ...OK
# Pizzeria Ristorante Puglia
# ...OK
# Boxenstopp
# ...OK
# Tante Blanka Höhengaststätte Neckarblick
# ...OK
# Weinstube Zaiß
# ...OK
# Gaststätte Krone
# ...OK
# Bärenschlößle
# ...OK
# Asia World
# ...OK
# Weinstube Kachelofen
# ...OK
# Noodle 1 Dining
# ...OK
# Hüftengold
# ...OK
# Hotel Ochsen
# ...OK
# Andalucia-Casamuu
# ...OK
# Cafe Tratsch
# ...OK
# The Gardener’s Nosh
# ...OK
# Ristorante Le Rose
# ...OK
# Daily Burger
# ...OK
# China Restaurant Palast
# ...OK
# Ristorante Pizzeria La Taverna da Enzo
# ...OK
# Regenbogen Imbiss
# ...OK
# El Taurino
# ...OK
# 1/1
# ...OK
# Yakiniku
# ...OK
# Rhythms Bar & Kitchen
# ...OK
# Due Stanze e Cucina
# ...OK
# Weinstube Fröhlich
# ...OK
# Taj Mahal
# ...OK
# Ristorante Italiani
# ...OK
# Restaurant Pizzeria Italia
# ...OK
# Ristorante Russo Wine Food and Eventlocation
# ...not found
# Da Nello
# ...OK
# Zum Becher
# ...OK
# Gaststätte Bierakademie
# ...OK
# Gasthof Riedsee
# ...OK
# Gasthaus zum Kreuz
# ...OK
# Neckarbiergarten
# ...OK
# Hirsch
# ...OK
# Köz Anatolische Spezialitäten
# ...OK
# Knausbira Stüble
# ...OK
# Tavola Calda
# ...OK
# La Bruschetta
# ...OK
# Amici
# ...OK
# Fischlounge
# ...OK
# Meister Lampe
# ...OK
# Sattlerei
# ...OK
# Il Terrazzino
# ...OK
# Weinstube Kochenbas
# ...OK
# Gaststätte Trompetle
# ...OK
# Gravity
# ...OK
# Triple B
# ...OK
# Icebreaker Bar im Hotel Pullman Fontana
# ...OK
# Taverna Sultan Saray
# ...OK
# Cube
# ...OK
# [m]eatery
# ...OK
# Bianco e Nero Ristorante
# ...OK
# Neuer Pfefferer
# ...OK
# Campioni
# ...OK
# Mauritius
# ...OK
# Divan Restaurant
# ...OK
# Funfo's
# ...OK
# Weinhalle 1896
# ...OK
# Diogenes Taverne
# ...OK
# Délice
# ...OK
# Los Locos Latinos
# ...OK
# Harmonie Ristorante
# ...OK
# Da Micci
# ...OK
# Wok's Tay Ho
# ...OK
# Gaststätte Schlesinger
# ...OK
# Eis-Cafe-Mario
# ...OK
# Insel Café
# ...OK
# La Taverna Da Pagano
# ...OK
# Café Babel
# ...OK
# Perbacco
# ...OK
# Gaststätte Ackermanns
# ...OK
# Alte Kanzlei
# ...OK
# Little Italy
# ...OK
# CBS-food,drinks&more café bar
# ...OK
# Alacati Beach Club Stuttgart
# ...OK
# Biergarten am Killesberg
# ...OK
# Löwen
# ...OK
# Restaurant Do
# ...OK
# Schwarzbach
# ...OK
# CBC
# ...OK
# Iko Sushi
# ...OK
# CaféHaus Veit
# ...OK
# The Dubliner
# ...OK
# KFC
# ...OK
# Kronprinz
# ...OK
# McDonald's
# ...OK
# Bertha’s Restaurant
# ...OK
# Asia Imbiss Van
# ...OK
# Gasthaus Waldhorn
# ...OK
# Bella Napoli
# ...OK
# Attimi
# ...OK
# Restaurant Van
# ...OK
# Netzer
# ...OK
# Sommerrain
# ...OK
# Rechberg
# ...OK
# McDonald's
# ...OK
# Ristorante Pizzeria La Piazzetta
# ...OK
# König Kebap
# ...OK
# Weinwirtschaft
# ...OK
# Alte Kelter
# ...OK
# Gourmetrestaurant Maestro
# ...OK
# Eleven
# ...OK
# Weinstube Heeb
# ...OK
# Thai Viet
# ...OK
# Kim's So
# ...OK
# BLOCK HOUSE Arnulf-Klett-Platz
# ...OK
# Serhat Döner Kebap
# ...OK
# Sportrestaurant Im Neckarpark
# ...OK
# Brauereiwirtshaus Sanwald
# ...OK
# Körle und Adam
# ...OK
# Hotel Royal
# ...OK
# Food Court
# ...OK
# Marktstüble
# ...OK
# Piroschka Konditorei & Café
# ...OK
# Zum Schluckspecht
# ...OK
# Gast
# ...OK
# Ambiente Africa
# ...OK
# Restaurant Dachswaldblick
# ...OK
# Palast der Republik
# ...OK
# PSV Vereinsgaststätte
# ...OK
# Café Justus
# ...OK
# Westkebap
# ...OK
# Weinstube Klink
# ...OK
# Finch
# ...OK
# Das Backparadies
# ...OK
# Asia-Thai-Sushi
# ...OK
# Drei Mohren
# ...OK
# Al Vecchio Mulino
# ...OK
# Da Peppone
# ...OK
# Tiffany Thaistyle
# ...OK
# Curryteria
# ...OK
# Römerhof
# ...OK
# Restaurant Kemnater Hof
# ...OK
# Zum Ackerbürger
# ...OK
# Vegi
# ...OK
# NEUE DÖNASTIE
# ...OK
# Festzeltbetriebe Göckelesmaier
# ...OK
# Da Fernando
# ...OK
# Hexle
# ...OK
# Gaststätte Kanonenbäck
# ...OK
# da Maria
# ...OK
# Restaurant Madagascar
# ...OK
# Gaststätte Stöckachstube
# ...OK
# Restaurant Granada
# ...OK
# Yuícery
# ...OK
# Burger King
# ...OK
# Frittenwerk
# ...OK
# La Stella
# ...OK
# La Bamboo
# ...OK
# Yaz
# ...OK
# Zur Sattlerei
# ...OK
# Ristorante Pulcinella
# ...OK
# Stoighofbesen
# ...OK
# Tokio Dining
# ...OK
# Le Cassoulet
# ...OK
# Sehne Backwaren
# ...OK
# The Auld Rogue
# ...OK
# Kantinchen
# ...OK
# Roseneck da Linda
# ...OK
# Shira Restoran Kurdisch-Türkische Spezialitäten
# ...OK
# Da Domenico
# ...OK
# Zum Golf
# ...OK
# Im Schnitzbiegel
# ...OK
# Vfl bei Stogi
# ...OK
# Hotalo
# ...OK
# Brauhaus Schönbuch
# ...OK
# Bäckerhaus Veit Café
# ...OK
# Gaststätte Ramsbachtal
# ...OK
# Ali Baba
# ...OK
# Gaststätte Hondler
# ...OK
# Der Rote Hirsch
# ...OK
# Café Olé
# ...OK
# Mezzogiorno
# ...OK
# Mediterraneo
# ...OK
# Bei Kosta
# ...OK
# Hotel Neuwirtshaus
# ...OK
# Sausalitos
# ...OK
# Bella Napoli
# ...OK
# Gaststätte Gaisburgstüble
# ...OK
# The Legend of Floating Market
# ...OK
# Waldheim Restaurant
# ...OK
# Heimgarten St. Josef
# ...OK
# Viet Wok
# ...OK
# Subway
# ...OK
# McDonald's
# ...OK
# Restaurant im Mercedes-Benz Museum
# ...OK
# Zom Baecka Dais
# ...OK
# Kashmir
# ...OK
# River Kwai
# ...OK
# Wisag Kantine
# ...OK
# Gaststätte Lamm
# ...OK
# Houstons Fine Burrito Company
# ...OK
# Oh my Burger
# ...OK
# Tapach-Gärtner
# ...OK
# Huong Viet
# ...OK
# Kickers Clubrestaurant
# ...OK
# Republic
# ...OK
# La Grazia
# ...OK
# Weber
# ...OK
# Five Guys
# ...OK
# d'r Knaudl
# ...OK
# Turn- und Sportverein Weilimdorf 1948 e.V.
# ...OK
# Namaste India
# ...OK
# Ristorante Elisa Alte Post
# ...OK
# Gaststätte Ochsen
# ...OK
# Biergarten im Schlossgarten
# ...OK
# Gasthaus zur Linde
# ...OK
# Mensa Stuttgart -Vaihingen
# ...OK
# Turnerbund Gaisburg 1886 e.V.
# ...OK
# Café am Markt
# ...OK
# Restaurant Muckenstüble
# ...OK
# Gaststätte Schwanen
# ...OK
# Sophie´s Brauhaus
# ...OK
# Schmidener Pizza & Kebaphaus
# ...OK
# Vietal Kitchen Stuttgart
# ...OK
# Trattoria da Peppe
# ...OK
# Pizzeria Adler
# ...OK
# pane e vino
# ...OK
# Biergarten Klingenbach
# ...OK
# QQ Fusion
# ...OK
# Gaststätte Jakobsbrunnen
# ...OK
# Höhengaststätte Hummelgraben
# ...OK
# Top Tennis
# ...OK
# Landschloss Korntal
# ...OK
# Schnitzelkönig
# ...OK
# Kirchtal
# ...OK
# TinTin
# ...OK
# Cafe Casa
# ...OK
# Jake's Diner Bar
# ...OK
# Rolands Maultaschen
# ...OK
# Burger House
# ...OK
# Onkel Otto
# ...OK
# Taverna Ouzeri Kolokotronis
# ...OK
# EZOM KEBAP
# ...OK
# Trattoria Santa Lucia
# ...OK
# Star Kebap
# ...OK
# Naturfreundehaus Fuchsrain
# ...OK
# Mikomi
# ...OK
# Lamm Feuerbach
# ...OK
# Feuerbacher
# ...OK
# Otto Onkel
# ...OK
# Ehli Keyf Shisha Cafe
# ...OK
# WO
# ...OK
# China Restaurant Panda
# ...OK
# Osteria Tra Noi
# ...OK
# Cafe Le Theatre
# ...OK
# Rems La Pizza
# ...OK
# Ristorante Positano
# ...OK
# China-Restaurant Pavillion
# ...OK
# PAULANER am alten Postplatz
# ...OK
# Metzgerei Häfele
# ...OK
# Trattoria Riva
# ...OK
# BLOCK HOUSE Eberhardstraße
# ...OK
# Namaskar
# ...OK
# mokkam
# ...OK
# Snack Station 33
# ...not found
# Quan-An
# ...OK
# Pizzeria Da Cesare
# ...OK
# Köfteci Tuncay
# ...OK
# Sutsche
# ...OK
# Nouvel
# ...OK
# Imbiss Dinkelacker
# ...OK
# Asia-Fire-Wok
# ...OK
# Geschlossen Restaurant Vinayaga
# ...OK
# Wirtshaus zum Hotzenplotz
# ...OK
# Besen66
# ...OK
# El Camino
# ...OK
# Kaminrestaurant
# ...OK
# Zur alten Ziegelei
# ...OK
# Restaurant mo.town
# ...OK
# Taverna Elia
# ...OK
# Ristorante Sardegna
# ...OK
# Durgun Pizza Kebab
# ...OK
# Amani
# ...OK
# Adana Sofrasi
# ...OK
# Antep Haus
# ...OK
# Da Noi Due
# ...OK
# JET
# ...OK
# Bäckerei und Konditorei Friedrich Übele
# ...OK
# Restaurant A.C. Hotel Hoferer
# ...OK
# Kupferkessel
# ...OK
# Mozart
# ...OK
# Alter Hasen
# ...OK
# Safran
# ...OK
# Onkel Hasan's Grillhaus
# ...OK
# Restaurant Amazonica
# ...OK
# Gasthaus Krone
# ...OK
# Caffebar Hölderlin
# ...OK
# QQ Sushi Lounge
# ...OK
# Gasthaus Grünewald
# ...OK
# Hotel Krehls Linde
# ...OK
# Chen's Cooking Wok & Grill Restaurant
# ...OK
# Voglia di Pizza
# ...OK
# Brasserie Bo.vin
# ...OK
# Asia Bistro
# ...OK
# The Little Greek Taverna
# ...OK
# Shima
# ...OK
# Backstube Back & Snack
# ...OK
# Gaststätte Meteora
# ...OK
# Ratsstube-Poseidon
# ...OK
# Oettinger's
# ...OK
# Laurita Pizza Service
# ...OK
# Tarte & Törtchen
# ...OK
# Wiener Kaffeehaus
# ...OK
# Früchtle vom Schmidener Feld
# ...OK
# Schmieg's Kellerbesen
# ...OK
# McDonald's
# ...OK
# è la Vita
# ...OK
# Imbiss Beirut
# ...OK
# Achillion
# ...OK
# L'angolino
# ...OK
# Thai Corner
# ...OK
# China-Imbiss-Panda
# ...OK
# Asia Via He
# ...OK
# Pullman Stuttgart Fontana
# ...OK
# Lindenhof - Restaurant
# ...OK
# IXIR-Foodhouse
# ...OK
# Waldheim Raichberg
# ...OK
# Lotusblume
# ...OK
# Cannstatter Kebap Haus
# ...OK
# Flora & Fauna
# ...OK
# Cafebar Auszeit
# ...OK
# Vereinsheim Gartenfreunde Heslach
# ...OK
# Taverna Yol
# ...OK
# Hans Im Glück
# ...OK
# Restaurant Tsv Steinhaldenfeld
# ...OK
# 87 Barbecue & Bar
# ...OK
# Reiterstüble Gasthaus
# ...OK
# Restaurant Steinhalde
# ...OK
# Wienerwald
# ...OK
# Tagesbar
# ...OK
# The Burger Republic
# ...OK
# Restaurant Hermes
# ...OK
# Seyffer's
# ...OK
# Aral
# ...OK
# Ristorante La Pergola
# ...OK
# Burreatos
# ...OK
# Gaststätte Ritterstüble
# ...OK
# Trattoria Vivaldi
# ...OK
# NLV Pizzeria
# ...OK
# Jose y Joséfina
# ...OK
# Cafe anno 1897
# ...OK
# la bruschetta
# ...OK
# Dedemoğlu
# ...OK
# peperoncino
# ...OK
# Sportrestaurant Neuwirtshaus
# ...OK
# Restaurant Landhausstuben
# ...OK
# Da Domenico
# ...OK
# Hasen
# ...OK
# Mögle
# ...OK
# Injeera
# ...OK
# DLRG Gaststätte
# ...OK
# Max-Eyth-See
# ...OK
# Gasthaus Rössle
# ...OK
# Plieninger Most- und Weinbesen
# ...OK
# Sapori d'Italia
# ...OK
# Ilysia am Wallgraben
# ...OK
# Persian Restaurant
# ...OK
# Charisma Bootshaus
# ...OK
# Osteria
# ...OK
# Asia Imbiss Hop Sing
# ...OK
# Rosenau - Lokalität & Bühne
# ...OK
# Er Vaquita
# ...OK
# Reyerhof-Bistro
# ...OK
# Dilgelay Restaurant
# ...OK
# Roma Pizza
# ...OK
# Weinstube Unmüßig
# ...OK
# dr' Schbruchbeidl
# ...OK
# Thang Long
# ...OK
# Hiami Sushi Bar
# ...OK
# Gaststätte Solitudestüble
# ...OK
# Balino Belvedere
# ...OK
# Höhencafe am Killesberg
# ...OK
# Hotel Hirsch
# ...OK
# Stallbesen
# ...OK
# Sushi Hiro
# ...OK
# Schloss Solitude Gastronomie
# ...OK
# Day & Night Pizza
# ...OK
# Ristorante Mangia!
# ...OK
# Vereinsgaststätte der Gartenfreunde Grenzäcker
# ...OK
# Lek's
# ...OK
# MairDumont Kantine Eurest
# ...OK
# Esszimmer
# ...OK
# Ü das Café
# ...OK
# Max&Moritz 2
# ...OK
# Manar Restaurant
# ...OK
# Viertel
# ...OK
# Taverne Porto Eliá
# ...OK
# Harmonie
# ...OK
# Da Toni Pizza und Eis
# ...OK
# RED BLACK BURGER
# ...OK
# Alte Post
# ...OK
# PS! Theatergastronomie
# ...OK
# SchwabenSpeisen
# ...OK
# Oggi
# ...OK
# Pizzeria Salento
# ...OK
# Madame Hòa
# ...OK
# Noodle Box
# ...OK
# Pizza Fiesta
# ...OK
# Speiserestaurant der SpVgg Cannstatt
# ...OK
# Milchbar Killesberg
# ...OK
# Alt Sillenbucher Weinstube zum Schwanen
# ...OK
# La Commedia
# ...OK
# Aral Tankstelle
# ...OK
# Bei Poula
# ...OK
# Stäffele
# ...OK
# Restaurant Ganesha
# ...OK
# Cantina dei Dogi
# ...OK
# Meze Meze
# ...OK
# Luigi's Pizza
# ...OK
# Spielbank Stuttgart
# ...OK
# EatUp - Pizza, Pasta, Grillhähnchen und mehr
# ...OK
# The Green Stream
# ...not found
# Thai Thaani
# ...OK
# Tapas y Vino
# ...OK
# City Grill
# ...OK
# Gaststätte Linde
# ...OK
# Da Enzo Ristorante E Pizzeria
# ...OK
# Gaststätte Jägerhaus
# ...OK
# Retsinadiko
# ...OK
# Anmol
# ...OK
# Burger Deluxe
# ...OK
# Gasthaus Bären
# ...OK
# Poffers Café Stuttgart
# ...OK
# Thios Inn
# ...OK
# Asv Athletik-Sport-Verein Botnang von 1898 e.V.
# ...OK
# Mom's Cooking Greek
# ...OK
# Nuova Casa Pompa
# ...OK
# Weinstube zum Tröpfle
# ...OK
# Nostalgia di Napoli
# ...OK
# Il Punto
# ...OK
# Restaurant im türkisch-islamischen Zentrum
# ...OK
# Café Bar Bliss
# ...OK
# Dost Kebabhaus
# ...OK
# Super Jami
# ...OK
# Cafe Elflein
# ...OK
# Namaste India
# ...OK
# Wirtshaus Friedrichsruh
# ...OK
# Eiscafé Canaletto
# ...OK
# YAFA
# ...OK
# Tsimpo
# ...OK
# Verein Waldheim Zuffenhausen 1911 e.V.
# ...OK
# BO'TECA di vino
# ...OK
# Equator
# ...OK
# Hans Im Glück
# ...OK
# Topfgucker
# ...OK
# Nordsee
# ...OK
# Wirtsstube Emilie
# ...OK
# Pizza Amigo
# ...OK
# Gablenberger Pizza & Kebaphaus
# ...OK
# Burger King
# ...OK
# ristorante musica é
# ...OK
# Wiesenstüble
# ...OK
# Goi-Asia Gourmet Imbiss
# ...OK
# Greek Garden
# ...OK
# Eat Drink Man Woman
# ...OK
# La bonne Baguette
# ...OK
# Sushi Hao
# ...OK
# Die Metzgerei
# ...OK
# Chinese Wok Lieferservice
# ...OK
# Cantuccio
# ...OK
# Café Hoffeld
# ...OK
# Gasthaus zum Hirsch
# ...OK
# Naturgut am Hölderlinplatz
# ...OK
# Hongkong Imbiss
# ...OK
# Cafe Kaiserbau
# ...OK
# Stuttgarter Schlachthof
# ...OK
# Restaurant Fässle
# ...OK
# Gasthaus Johannesgarten
# ...OK
# d.carlos portugiesisches restaurant, Mitte-Süd, Stuttgart
# ...OK
# La Rinascente
# ...OK
# Sushi.Wrap
# ...OK
# Wirtshaus Troll
# ...OK
# Zur Weinsteige
# ...OK
# Alte Dorfschule
# ...OK
# Thai Orchidee
# ...OK
# Sushi & Wok
# ...OK
# Valle
# ...OK
# Siegel
# ...OK
# Sichuan
# ...OK
# Can Döner
# ...OK
# Yuoki
# ...OK
# Sakristei
# ...OK
# Café MuseO
# ...OK
# McDonald's
# ...OK
# Kurose
# ...OK
# Asia Viet Long
# ...OK
# Il Pomodoro
# ...OK
# Bonnie & Clyde
# ...OK
# Krua Thai Bolan
# ...OK
# Hans Im Glück
# ...OK
# Taverna Janni & Güllo
# ...OK

# %%
df_yelp['google_id'] = google_ids
df_yelp['google_name'] = google_names

# %%
# Copy and re-order columns. 
df_yelp_reordered = df_yelp[['yelp_id', 'google_id', 'yelp_name', 'google_name', 'address', 'categories', 
                  'price_level', 'avg_rating', 'review_count', 'photo_urls', 'latitude', 'longitude']]
df_yelp = df_yelp_reordered

# %%
df_yelp.head()
# Out:
#                   yelp_id                    google_id  \
# 1  6XKiHruNrTO8jDAcHLoR3w  ChIJF5m2rSLFmUcRH9sBPHwx3kM
# 2  0Ep-rCF4UVrz3ZJkd_gAXQ  ChIJOWEUrcvEmUcRqRXjZal8AZY
# 3  MVScl0YGy_ZkGb7iN58k-A  ChIJI_1zBlHbmUcROMi0FydapcE
# 4  KbIoL9bMYzCZDWxpWTcx0g  ChIJ6wNLZzPbmUcRrtanMZs8deo
# 5  LlLDMhhPeCKs4oyZxFQGaw  ChIJo1Y9RTjQmUcRnsk3LcgHomE
#
#                                yelp_name  \
# 1                   Bäckerhaus Veit Café
# 2                        Prince of India
# 3                            Bocca Buona
# 4  Weinwirtschaft | Weingut Franz Keller
# 5           Zum Adler Gasthaus Weinstube
#
#                              google_name  \
# 1                   Bäckerhaus Veit Café
# 2                        Prince of India
# 3                 Bocca Buona Restaurant
# 4  Weinwirtschaft | Weingut Franz Keller
# 5               Hotel & Restaurant Adler
#
#                                              address  \
# 1          [Epplestr. 1 b, 70597 Stuttgart, Germany]
# 2           [Urbanstr. 38, 70182 Stuttgart, Germany]
# 3  [Hauptstätter Str. 147, 70180 Stuttgart, Germany]
# 4        [Schillerstr. 23, 70173 Stuttgart, Germany]
# 5  [Alte Stuttgarter Str. 2, 70195 Stuttgart, Ger...
#
#                            categories price_level  avg_rating  review_count  \
# 1                   [Bakeries, Cafes]                     1.5             5
# 2                            [Indian]          €€         3.0            27
# 3                           [Italian]                     2.5             3
# 4  [International, German, Wine Bars]          €€         3.5            10
# 5                       [Restaurants]           €         5.0             3
#
#                                           photo_urls   latitude  longitude
# 1  [https://s3-media2.fl.yelpcdn.com/bphoto/M0vpn...  48.749109   9.169810
# 2  [https://s3-media4.fl.yelpcdn.com/bphoto/rwxyn...  48.778664   9.187046
# 3  [https://s3-media4.fl.yelpcdn.com/bphoto/NA4u_...  48.764643   9.169958
# 4  [https://s3-media2.fl.yelpcdn.com/bphoto/l0icD...  48.782600   9.182460
# 5  [https://s3-media2.fl.yelpcdn.com/bphoto/6_MBr...  48.778200   9.124740

# %%
# Drop column 'google_name', as it may not be saved permanently
df_yelp = df_yelp.drop(columns=['google_name'])

# %%
# Write to file
df_yelp.to_csv('yelp_restaurants.csv', index=False)
df_yelp.to_excel('yelp_restaurants.xlsx', index=False)
